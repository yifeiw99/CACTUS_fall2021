# %% [markdown]
# Media Cloud: Sources and Collections
# ====================================
#
# At this point you should be ready to query Media Cloud for data. **This notebook demonstrates how to browse and download information about the media sources and collections within Media Cloud system**. This explores some of the API methods under the hood of our [Source Manager tool](https://sources.mediacloud.org), which is used to browse and administer sources and collections in our system.
#
# Media Cloud is a suite of web tools to support research into media coverage online. The underlying database has 1.5 billion stories (as of early 2020). Every open-web news story is connected to a `media` source. Sources are grouped together into collections (via `tags`). Our primary collections are [geography-based](https://sources.mediacloud.org/#/collections/country-and-state) (at the national and provider/state level).
#
# We regularly scrape RSS feeds from a small set of our sources (around 60k as of early 2020). We are slowly rolling out the ability to ingest stories from news stories via their sitemap files (the hard part is determining which URLs arenews story pages and what are not). Other stories are discovered and added in via spidering links or finding a share of a news URL on social media. We don't advise using our entire database because it is skewed towards the topics of investigations ourselves, and collaborating researchers, have done. You can mitigate this by using the afore-mentioned geographic collections.
#
# Our Python API exposes a few methods that are particularly helpful for looking at sources, their associated metadata, and collections:
#
# * `mediaList`: useful to search for media, or page through all the media in a collection ([documentation](https://github.com/berkmancenter/mediacloud/blob/master/doc/api_2_0_spec/api_2_0_spec.md#apiv2medialist))
# * `media`: all metadata data about one media source, by `media_id` ([documentation](https://github.com/berkmancenter/mediacloud/blob/master/doc/api_2_0_spec/api_2_0_spec.md#apiv2mediasingle))
# * `feedList`: page through any RSS feeds associated with a media source ([documentation](https://github.com/berkmancenter/mediacloud/blob/master/doc/api_2_0_spec/api_2_0_spec.md#apiv2feedslist))
# * `tagSet`: collecitons are grouped into `tag_sets` ([documentation](https://github.com/berkmancenter/mediacloud/blob/master/doc/api_2_0_spec/api_2_0_spec.md#apiv2tag_setssingle))
# * `tagList`: list all the collections in a `tag_set` ([documentation](https://github.com/berkmancenter/mediacloud/blob/master/doc/api_2_0_spec/api_2_0_spec.md#apiv2tag_setslist))
# * `tag`: information about a collection ([documentation](https://github.com/berkmancenter/mediacloud/blob/master/doc/api_2_0_spec/api_2_0_spec.md#apiv2tagssingle))

# %% [markdown]
# ## Setup

# %%
# Grab your API key from the environment variable and create a client for talking to Media Cloud
import os, mediacloud.api
from dotenv import load_dotenv
from IPython.display import JSON
load_dotenv()  # load config from .env file
mc = mediacloud.api.MediaCloud('')
mediacloud.__version__
# Out:
# '3.12.5'

# %% [markdown]
# ## Searching for Media Sources
#
# You can search for specific media, or media matching a set of criteria.

# %%
# try to find a media source based on its URL
matching_sources = mc.mediaList(name_like='hindustantimes', sort='num_stories')
matching_sources
# Out:
# [{'is_healthy': True,
#   'is_monitored': False,
#   'media_id': 39872,
#   'media_source_tags': [{'description': 'Large list of all sites collected by the Europe Media Monitor project (http://emm.newsbrief.eu). Added in October of 2012. Includes anywhere from five to dozens of sources from almost every country.  This is our main set for broad coverage of international mainstream media.',
#     'label': 'Europe Media Monitor',
#     'media_id': 39872,
#     'show_on_media': True,
#     'show_on_stories': None,
#     'tag': 'europe_media_monitor_20121015',
#     'tag_set': 'collection',
#     'tag_sets_id': 5,
#     'tagged_date': None,
#     'tags_id': 8876474},
#    {'description': None,
#     'label': None,
#     'media_id': 39872,
#     'show_on_media': False,
#     'show_on_stories': None,
#     'tag': 'webnews',
#     'tag_set': 'emm_type',
#     'tag_sets_id': 554,
#     'tagged_date': None,
#     'tags_id': 8876475},
#    {'description': None,
#     'label': None,
#     'media_id': 39872,
#     'show_on_media': False,
#     'show_on_stories': None,
#     'tag': 'general_news',
#     'tag_set': 'emm_subject',
#     'tag_sets_id': 555,
#     'tagged_date': None,
#     'tags_id': 8876476},
#    {'description': None,
#     'label': None,
#     'media_id': 39872,
#     'show_on_media': False,
#     'show_on_stories': None,
#     'tag': 'national',
#     'tag_set': 'emm_category',
#     'tag_sets_id': 558,
#     'tagged_date': None,
#     'tags_id': 8876479},
#    {'description': None,
#     'label': None,
#     'media_id': 39872,
#     'show_on_media': False,
#     'show_on_stories': None,
#     'tag': 'en',
#     'tag_set': 'emm_lang',
#     'tag_sets_id': 559,
#     'tagged_date': None,
#     'tags_id': 8876484},
#    {'description': None,
#     'label': None,
#     'media_id': 39872,
#     'show_on_media': False,
#     'show_on_stories': None,
#     'tag': 'asia',
#     'tag_set': 'emm_region',
#     'tag_sets_id': 557,
#     'tagged_date': None,
#     'tags_id': 8876504},
#    {'description': 'Media sources labelled as from India in the European Media Monitor tool (2014)',
#     'label': 'India',
#     'media_id': 39872,
#     'show_on_media': True,
#     'show_on_stories': None,
#     'tag': 'IN',
#     'tag_set': 'emm_country',
#     'tag_sets_id': 556,
#     'tagged_date': None,
#     'tags_id': 8876655},
#    {'description': None,
#     'label': None,
#     'media_id': 39872,
#     'show_on_media': None,
#     'show_on_stories': None,
#     'tag': 'gates_20160203',
#     'tag_set': 'collection',
#     'tag_sets_id': 5,
#     'tagged_date': None,
#     'tags_id': 9137547},
#    {'description': None,
#     'label': None,
#     'media_id': 39872,
#     'show_on_media': None,
#     'show_on_stories': None,
#     'tag': 'gates_india_20160203',
#     'tag_set': 'collection',
#     'tag_sets_id': 5,
#     'tagged_date': None,
#     'tags_id': 9137550},
#    {'description': None,
#     'label': None,
#     'media_id': 39872,
#     'show_on_media': None,
#     'show_on_stories': None,
#     'tag': 'india_alexa_20160318',
#     'tag_set': 'collection',
#     'tag_sets_id': 5,
#     'tagged_date': None,
#     'tags_id': 9172519},
#    {'description': 'null',
#     'label': 'null',
#     'media_id': 39872,
#     'show_on_media': False,
#     'show_on_stories': None,
#     'tag': 'null',
#     'tag_set': 'collection',
#     'tag_sets_id': 5,
#     'tagged_date': None,
#     'tags_id': 9172520},
#    {'description': None,
#     'label': None,
#     'media_id': 39872,
#     'show_on_media': None,
#     'show_on_stories': None,
#     'tag': 'feedly_india_20160420',
#     'tag_set': 'collection',
#     'tag_sets_id': 5,
#     'tagged_date': None,
#     'tags_id': 9197881},
#    {'description': None,
#     'label': None,
#     'media_id': 39872,
#     'show_on_media': None,
#     'show_on_stories': None,
#     'tag': 'india_alexa_pruned_new_20160509',
#     'tag_set': 'collection',
#     'tag_sets_id': 5,
#     'tagged_date': None,
#     'tags_id': 9201394},
#    {'description': 'Manually curated set of Indian sources.',
#     'label': 'India',
#     'media_id': 39872,
#     'show_on_media': False,
#     'show_on_stories': None,
#     'tag': 'India',
#     'tag_set': 'collection',
#     'tag_sets_id': 5,
#     'tagged_date': None,
#     'tags_id': 9201395},
#    {'description': 'Sources in English listed as "national" for every country in the ABYZ directory of online news sources. This contains around 1,500 sources. ',
#     'label': 'Global English Language Sources ',
#     'media_id': 39872,
#     'show_on_media': True,
#     'show_on_stories': None,
#     'tag': 'Global_English_Language_Sources_',
#     'tag_set': 'collection',
#     'tag_sets_id': 5,
#     'tagged_date': None,
#     'tags_id': 9272347},
#    {'description': 'Published in India',
#     'label': 'India',
#     'media_id': 39872,
#     'show_on_media': True,
#     'show_on_stories': None,
#     'tag': 'pub_IND',
#     'tag_set': 'pub_country',
#     'tag_sets_id': 1935,
#     'tagged_date': None,
#     'tags_id': 9353533},
#    {'description': 'Sources categorized into the Right quintile based on relative number of tweets of election story urls by Clinton vs. Trump retweeters.  This version of the set has low certainity for individual members and so should be used only for aggregate question rather than the labeling of individual members.',
#     'label': 'Tweeted Mostly by Trump Followers 2016 (US Right 2016)',
#     'media_id': 39872,
#     'show_on_media': True,
#     'show_on_stories': None,
#     'tag': 'Tweeted_Mostly_by_Trump_Followers_2016__US_Right_2016_',
#     'tag_set': 'retweet_partisanship_2016_count_10',
#     'tag_sets_id': 1959,
#     'tagged_date': None,
#     'tags_id': 9360524},
#    {'description': 'Media sources for which the primary language is English',
#     'label': 'English',
#     'media_id': 39872,
#     'show_on_media': True,
#     'show_on_stories': None,
#     'tag': 'en',
#     'tag_set': 'primary_language',
#     'tag_sets_id': 1969,
#     'tagged_date': None,
#     'tags_id': 9361422},
#    {'description': 'Media sources for which the majority subject country is Republic of India.',
#     'label': 'Republic of India',
#     'media_id': 39872,
#     'show_on_media': None,
#     'show_on_stories': None,
#     'tag': 'Republic of India',
#     'tag_set': 'subject_country',
#     'tag_sets_id': 1970,
#     'tagged_date': None,
#     'tags_id': 9361509},
#    {'description': 'This source is primarly a print publication. Use this for newspapers and magazines. Examples: New York Times, The Economist.',
#     'label': 'Print Native',
#     'media_id': 39872,
#     'show_on_media': True,
#     'show_on_stories': None,
#     'tag': 'print_native',
#     'tag_set': 'media_format',
#     'tag_sets_id': 1972,
#     'tagged_date': None,
#     'tags_id': 32018491},
#    {'description': 'Media is largely about India',
#     'label': 'India - National',
#     'media_id': 39872,
#     'show_on_media': True,
#     'show_on_stories': False,
#     'tag': 'India___National',
#     'tag_set': 'geographic_collection',
#     'tag_sets_id': 15765102,
#     'tagged_date': None,
#     'tags_id': 34412118},
#    {'description': 'Media is largely about India - State & Local',
#     'label': 'India - State & Local',
#     'media_id': 39872,
#     'show_on_media': True,
#     'show_on_stories': False,
#     'tag': 'India___State___Local',
#     'tag_set': 'geographic_collection',
#     'tag_sets_id': 15765102,
#     'tagged_date': None,
#     'tags_id': 38379954},
#    {'description': 'Published in Delhi, India',
#     'label': 'Delhi, India',
#     'media_id': 39872,
#     'show_on_media': False,
#     'show_on_stories': False,
#     'tag': 'pub_IN-DL',
#     'tag_set': 'pub_state',
#     'tag_sets_id': 1962,
#     'tagged_date': None,
#     'tags_id': 38379958},
#    {'description': 'Media is largely about Delhi, India - State & Local',
#     'label': 'Delhi, India - State & Local',
#     'media_id': 39872,
#     'show_on_media': True,
#     'show_on_stories': False,
#     'tag': 'geo_IN-DL',
#     'tag_set': 'geographic_collection',
#     'tag_sets_id': 15765102,
#     'tagged_date': None,
#     'tags_id': 38379959},
#    {'description': 'Media is largely about India',
#     'label': 'India - National',
#     'media_id': 39872,
#     'show_on_media': None,
#     'show_on_stories': None,
#     'tag': 'geo_IND',
#     'tag_set': 'ABYZ',
#     'tag_sets_id': 15765105,
#     'tagged_date': None,
#     'tags_id': 48169961},
#    {'description': 'Media is largely about Delhi, India - State & Local',
#     'label': 'Delhi, India - State & Local',
#     'media_id': 39872,
#     'show_on_media': None,
#     'show_on_stories': None,
#     'tag': 'geo_IN-DL',
#     'tag_set': 'ABYZ',
#     'tag_sets_id': 15765105,
#     'tagged_date': None,
#     'tags_id': 48170041},
#    {'description': 'Media is largely about India - State & Local',
#     'label': 'India - State & Local',
#     'media_id': 39872,
#     'show_on_media': None,
#     'show_on_stories': None,
#     'tag': 'geo_IND_state',
#     'tag_set': 'ABYZ',
#     'tag_sets_id': 15765105,
#     'tagged_date': None,
#     'tags_id': 48170044},
#    {'description': 'Media for which url sharing on twitter is aligned with the U.S. partisan center right',
#     'label': 'Tweeted Somewhat More by Followers of Conservative Politicians 2019 (US Center Right 2019)',
#     'media_id': 39872,
#     'show_on_media': True,
#     'show_on_stories': False,
#     'tag': 'Tweeted_Somewhat_More_by_Followers_of_Conservative_Politicians_2019__US_Center_Right_2019_',
#     'tag_set': 'twitter_partisanship',
#     'tag_sets_id': 15765109,
#     'tagged_date': '2020-06-04',
#     'tags_id': 200363062}],
#   'name': 'HindustanTimes',
#   'num_sentences_90': 8.1,
#   'num_stories_90': 0.33,
#   'public_notes': '',
#   'start_date': '2016-08-08',
#   'url': 'http://www.hindustantimes.com/',
#   'metadata': {'pub_country': {'description': 'Published in India',
#     'label': 'India',
#     'media_id': 39872,
#     'show_on_media': True,
#     'show_on_stories': None,
#     'tag': 'pub_IND',
#     'tag_set': 'pub_country',
#     'tag_sets_id': 1935,
#     'tagged_date': None,
#     'tags_id': 9353533},
#    'pub_state': {'description': 'Published in Delhi, India',
#     'label': 'Delhi, India',
#     'media_id': 39872,
#     'show_on_media': False,
#     'show_on_stories': False,
#     'tag': 'pub_IN-DL',
#     'tag_set': 'pub_state',
#     'tag_sets_id': 1962,
#     'tagged_date': None,
#     'tags_id': 38379958},
#    'language': {'description': 'Media sources for which the primary language is English',
#     'label': 'English',
#     'media_id': 39872,
#     'show_on_media': True,
#     'show_on_stories': None,
#     'tag': 'en',
#     'tag_set': 'primary_language',
#     'tag_sets_id': 1969,
#     'tagged_date': None,
#     'tags_id': 9361422},
#    'about_country': {'description': 'Media sources for which the majority subject country is Republic of India.',
#     'label': 'Republic of India',
#     'media_id': 39872,
#     'show_on_media': None,
#     'show_on_stories': None,
#     'tag': 'Republic of India',
#     'tag_set': 'subject_country',
#     'tag_sets_id': 1970,
#     'tagged_date': None,
#     'tags_id': 9361509},
#    'media_type': {'description': 'This source is primarly a print publication. Use this for newspapers and magazines. Examples: New York Times, The Economist.',
#     'label': 'Print Native',
#     'media_id': 39872,
#     'show_on_media': True,
#     'show_on_stories': None,
#     'tag': 'print_native',
#     'tag_set': 'media_format',
#     'tag_sets_id': 1972,
#     'tagged_date': None,
#     'tags_id': 32018491}}}]

# %% [markdown]
# The first thing you'll notice is that our sources are rather noisy. We are trying to move to a model where each told level domain is a media source (with a handful of exceptions), but we haven't finished that work yet. So for it can be useful to sort there results by how content content they produce (ie. `sort='num_stories'`).

# %% [markdown]
# ### Searching for Media by Metadata
# Media sources have lots and lots of `tags` one them. Tags are used to represent many things in Media Cloud. In this case two relevant uses are:
# * tags are used to cluster media sources in collections
# * tags are used to add metadata to media sources - these are helpfully parsed out for you by the API client in the `metadata` property

# %%
# use metadata tags to find media published in India in English
TAG_PUBLISHED_IN_INDIA = 9353533
TAG_PUBLISHED_IN_MOSTLY_ENGLISH = 9361422
# this `tags_id_X` syntax is a little hokey, but it what we built quickly
# `tags_id_X` clauses are AND'ed together, while the array of values for each are OR'ed together
indian_english_sources = mc.mediaList(tags_id_1=[TAG_PUBLISHED_IN_INDIA],
                                      tags_id_2=[TAG_PUBLISHED_IN_MOSTLY_ENGLISH],
                                      sort='num_stories')
[m['url'] for m in indian_english_sources]
# Out:
# ['http://timesofindia.com/',
#  'http://expressindia.com/',
#  'http://www.thehindu.com/',
#  'http://www.hindu.com',
#  'http://newindianexpress.com/#spider',
#  'http://news18.com/',
#  'https://economictimes.indiatimes.com/',
#  'http://indianexpress.com/',
#  'http://economictimes.indiatimes.com/et-now',
#  'http://articles.economictimes.indiatimes.com',
#  'http://ibnlive.in.com',
#  'https://www.news18.com/',
#  'http://profit.ndtv.com/',
#  'http://www.business-standard.com',
#  'https://news.google.com/news/?ned=hi_in',
#  'http://www.frontline.in/#spider',
#  'https://news.google.com/news/?ned=te_in',
#  'http://www.newkerala.com#spider',
#  'https://news.google.com/news/?ned=ml_in',
#  'http://epaper.freepressjournal.in/t/8345/Bhopal/']

# %% [markdown]
# ### Paging Through Media Lists & Saving Result CSVs
# But you probably want to page through results to see all the matching sources in our system. `mediaList` supports that thorugh the `last_media_id` param.

# %%
# page through a list of media list results
def all_media_list(**kwargs):
    last_media_id = None
    more_results = True
    matching_media = []
    while more_results:
        media_page = mc.mediaList(**kwargs, last_media_id=last_media_id)
        print("  got a page of {} matching media".format(len(media_page)))
        if len(media_page) == 0:
            more_results = False
        else:
            matching_media += media_page
            last_media_id = media_page[-1]['media_id']
    return matching_media
all_indian_english_sources = all_media_list(tags_id_1=[TAG_PUBLISHED_IN_INDIA],
                                            tags_id_2=[TAG_PUBLISHED_IN_MOSTLY_ENGLISH],
                                            sort='num_stories',
                                            rows=100)
"found {} matching sources total".format(len(all_indian_english_sources))
# Out:
#   got a page of 100 matching media
#   got a page of 100 matching media
#   got a page of 73 matching media
#   got a page of 24 matching media
#   got a page of 10 matching media
#   got a page of 3 matching media
#   got a page of 0 matching media
# 'found 310 matching sources total'

# %%
# and you may want to save that as a CSV, like Source Manager lets you do online
fieldnames = ['media_id', 'url', 'name',
              'pub_country', 'pub_state', 'primary_language', 'subject_country', 'media_type',
              'public_notes', 'stories_per_day', 'first_story']
for m in all_indian_english_sources: # do some data prep to make it easy to output
    m['pub_country'] = m['metadata']['pub_country']['tag'] if m['metadata']['pub_country'] else None
    m['pub_state'] = m['metadata']['pub_state']['tag'] if m['metadata']['pub_state'] else None
    m['primary_language'] = m['metadata']['language']['tag'] if m['metadata']['language'] else None
    m['subject_country'] = m['metadata']['about_country']['tag'] if m['metadata']['about_country'] else None
    m['media_type'] = m['metadata']['media_type']['tag'] if m['metadata']['media_type'] else None
    m['stories_per_day'] = m['num_stories_90']
    m['first_story'] = m['start_date']
# and write a CSV
import csv
with open('media-list.csv', 'w', newline='',encoding = 'utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames, extrasaction='ignore')
    writer.writeheader()
    for s in all_indian_english_sources:
        writer.writerow(s)

# %% [markdown]
# ## Media Source Feeds
# Media Sources are created manually, or automatically generated by our system when a story is ingested from a domain we have not seen before. In the latter situation, a placeholder inactive RSS feed is generated to maintain database consistency (this feed usually has _"#spidered"_ on the end of its URL). For the limited number of sources that we ingest from daily, we have manually and automatically created RSS feeds (see our [`feed_seeker` package](https://github.com/mitmedialab/feed_seeker)).
# ```
# media source
#   ↳ feed
#     ↳ story
# ```

# %%
# learn about the first result from above, which is our canonical one for the Hindustan Times
hindustan_times = mc.media(matching_sources[0]['media_id'])
hindustan_times
# Out:
# {'is_healthy': True,
#  'is_monitored': False,
#  'media_id': 39872,
#  'media_source_tags': [{'description': 'Large list of all sites collected by the Europe Media Monitor project (http://emm.newsbrief.eu). Added in October of 2012. Includes anywhere from five to dozens of sources from almost every country.  This is our main set for broad coverage of international mainstream media.',
#    'label': 'Europe Media Monitor',
#    'media_id': 39872,
#    'show_on_media': True,
#    'show_on_stories': None,
#    'tag': 'europe_media_monitor_20121015',
#    'tag_set': 'collection',
#    'tag_sets_id': 5,
#    'tagged_date': None,
#    'tags_id': 8876474},
#   {'description': None,
#    'label': None,
#    'media_id': 39872,
#    'show_on_media': False,
#    'show_on_stories': None,
#    'tag': 'webnews',
#    'tag_set': 'emm_type',
#    'tag_sets_id': 554,
#    'tagged_date': None,
#    'tags_id': 8876475},
#   {'description': None,
#    'label': None,
#    'media_id': 39872,
#    'show_on_media': False,
#    'show_on_stories': None,
#    'tag': 'general_news',
#    'tag_set': 'emm_subject',
#    'tag_sets_id': 555,
#    'tagged_date': None,
#    'tags_id': 8876476},
#   {'description': None,
#    'label': None,
#    'media_id': 39872,
#    'show_on_media': False,
#    'show_on_stories': None,
#    'tag': 'national',
#    'tag_set': 'emm_category',
#    'tag_sets_id': 558,
#    'tagged_date': None,
#    'tags_id': 8876479},
#   {'description': None,
#    'label': None,
#    'media_id': 39872,
#    'show_on_media': False,
#    'show_on_stories': None,
#    'tag': 'en',
#    'tag_set': 'emm_lang',
#    'tag_sets_id': 559,
#    'tagged_date': None,
#    'tags_id': 8876484},
#   {'description': None,
#    'label': None,
#    'media_id': 39872,
#    'show_on_media': False,
#    'show_on_stories': None,
#    'tag': 'asia',
#    'tag_set': 'emm_region',
#    'tag_sets_id': 557,
#    'tagged_date': None,
#    'tags_id': 8876504},
#   {'description': 'Media sources labelled as from India in the European Media Monitor tool (2014)',
#    'label': 'India',
#    'media_id': 39872,
#    'show_on_media': True,
#    'show_on_stories': None,
#    'tag': 'IN',
#    'tag_set': 'emm_country',
#    'tag_sets_id': 556,
#    'tagged_date': None,
#    'tags_id': 8876655},
#   {'description': None,
#    'label': None,
#    'media_id': 39872,
#    'show_on_media': None,
#    'show_on_stories': None,
#    'tag': 'gates_20160203',
#    'tag_set': 'collection',
#    'tag_sets_id': 5,
#    'tagged_date': None,
#    'tags_id': 9137547},
#   {'description': None,
#    'label': None,
#    'media_id': 39872,
#    'show_on_media': None,
#    'show_on_stories': None,
#    'tag': 'gates_india_20160203',
#    'tag_set': 'collection',
#    'tag_sets_id': 5,
#    'tagged_date': None,
#    'tags_id': 9137550},
#   {'description': None,
#    'label': None,
#    'media_id': 39872,
#    'show_on_media': None,
#    'show_on_stories': None,
#    'tag': 'india_alexa_20160318',
#    'tag_set': 'collection',
#    'tag_sets_id': 5,
#    'tagged_date': None,
#    'tags_id': 9172519},
#   {'description': 'null',
#    'label': 'null',
#    'media_id': 39872,
#    'show_on_media': False,
#    'show_on_stories': None,
#    'tag': 'null',
#    'tag_set': 'collection',
#    'tag_sets_id': 5,
#    'tagged_date': None,
#    'tags_id': 9172520},
#   {'description': None,
#    'label': None,
#    'media_id': 39872,
#    'show_on_media': None,
#    'show_on_stories': None,
#    'tag': 'feedly_india_20160420',
#    'tag_set': 'collection',
#    'tag_sets_id': 5,
#    'tagged_date': None,
#    'tags_id': 9197881},
#   {'description': None,
#    'label': None,
#    'media_id': 39872,
#    'show_on_media': None,
#    'show_on_stories': None,
#    'tag': 'india_alexa_pruned_new_20160509',
#    'tag_set': 'collection',
#    'tag_sets_id': 5,
#    'tagged_date': None,
#    'tags_id': 9201394},
#   {'description': 'Manually curated set of Indian sources.',
#    'label': 'India',
#    'media_id': 39872,
#    'show_on_media': False,
#    'show_on_stories': None,
#    'tag': 'India',
#    'tag_set': 'collection',
#    'tag_sets_id': 5,
#    'tagged_date': None,
#    'tags_id': 9201395},
#   {'description': 'Sources in English listed as "national" for every country in the ABYZ directory of online news sources. This contains around 1,500 sources. ',
#    'label': 'Global English Language Sources ',
#    'media_id': 39872,
#    'show_on_media': True,
#    'show_on_stories': None,
#    'tag': 'Global_English_Language_Sources_',
#    'tag_set': 'collection',
#    'tag_sets_id': 5,
#    'tagged_date': None,
#    'tags_id': 9272347},
#   {'description': 'Published in India',
#    'label': 'India',
#    'media_id': 39872,
#    'show_on_media': True,
#    'show_on_stories': None,
#    'tag': 'pub_IND',
#    'tag_set': 'pub_country',
#    'tag_sets_id': 1935,
#    'tagged_date': None,
#    'tags_id': 9353533},
#   {'description': 'Sources categorized into the Right quintile based on relative number of tweets of election story urls by Clinton vs. Trump retweeters.  This version of the set has low certainity for individual members and so should be used only for aggregate question rather than the labeling of individual members.',
#    'label': 'Tweeted Mostly by Trump Followers 2016 (US Right 2016)',
#    'media_id': 39872,
#    'show_on_media': True,
#    'show_on_stories': None,
#    'tag': 'Tweeted_Mostly_by_Trump_Followers_2016__US_Right_2016_',
#    'tag_set': 'retweet_partisanship_2016_count_10',
#    'tag_sets_id': 1959,
#    'tagged_date': None,
#    'tags_id': 9360524},
#   {'description': 'Media sources for which the primary language is English',
#    'label': 'English',
#    'media_id': 39872,
#    'show_on_media': True,
#    'show_on_stories': None,
#    'tag': 'en',
#    'tag_set': 'primary_language',
#    'tag_sets_id': 1969,
#    'tagged_date': None,
#    'tags_id': 9361422},
#   {'description': 'Media sources for which the majority subject country is Republic of India.',
#    'label': 'Republic of India',
#    'media_id': 39872,
#    'show_on_media': None,
#    'show_on_stories': None,
#    'tag': 'Republic of India',
#    'tag_set': 'subject_country',
#    'tag_sets_id': 1970,
#    'tagged_date': None,
#    'tags_id': 9361509},
#   {'description': 'This source is primarly a print publication. Use this for newspapers and magazines. Examples: New York Times, The Economist.',
#    'label': 'Print Native',
#    'media_id': 39872,
#    'show_on_media': True,
#    'show_on_stories': None,
#    'tag': 'print_native',
#    'tag_set': 'media_format',
#    'tag_sets_id': 1972,
#    'tagged_date': None,
#    'tags_id': 32018491},
#   {'description': 'Media is largely about India',
#    'label': 'India - National',
#    'media_id': 39872,
#    'show_on_media': True,
#    'show_on_stories': False,
#    'tag': 'India___National',
#    'tag_set': 'geographic_collection',
#    'tag_sets_id': 15765102,
#    'tagged_date': None,
#    'tags_id': 34412118},
#   {'description': 'Media is largely about India - State & Local',
#    'label': 'India - State & Local',
#    'media_id': 39872,
#    'show_on_media': True,
#    'show_on_stories': False,
#    'tag': 'India___State___Local',
#    'tag_set': 'geographic_collection',
#    'tag_sets_id': 15765102,
#    'tagged_date': None,
#    'tags_id': 38379954},
#   {'description': 'Published in Delhi, India',
#    'label': 'Delhi, India',
#    'media_id': 39872,
#    'show_on_media': False,
#    'show_on_stories': False,
#    'tag': 'pub_IN-DL',
#    'tag_set': 'pub_state',
#    'tag_sets_id': 1962,
#    'tagged_date': None,
#    'tags_id': 38379958},
#   {'description': 'Media is largely about Delhi, India - State & Local',
#    'label': 'Delhi, India - State & Local',
#    'media_id': 39872,
#    'show_on_media': True,
#    'show_on_stories': False,
#    'tag': 'geo_IN-DL',
#    'tag_set': 'geographic_collection',
#    'tag_sets_id': 15765102,
#    'tagged_date': None,
#    'tags_id': 38379959},
#   {'description': 'Media is largely about India',
#    'label': 'India - National',
#    'media_id': 39872,
#    'show_on_media': None,
#    'show_on_stories': None,
#    'tag': 'geo_IND',
#    'tag_set': 'ABYZ',
#    'tag_sets_id': 15765105,
#    'tagged_date': None,
#    'tags_id': 48169961},
#   {'description': 'Media is largely about Delhi, India - State & Local',
#    'label': 'Delhi, India - State & Local',
#    'media_id': 39872,
#    'show_on_media': None,
#    'show_on_stories': None,
#    'tag': 'geo_IN-DL',
#    'tag_set': 'ABYZ',
#    'tag_sets_id': 15765105,
#    'tagged_date': None,
#    'tags_id': 48170041},
#   {'description': 'Media is largely about India - State & Local',
#    'label': 'India - State & Local',
#    'media_id': 39872,
#    'show_on_media': None,
#    'show_on_stories': None,
#    'tag': 'geo_IND_state',
#    'tag_set': 'ABYZ',
#    'tag_sets_id': 15765105,
#    'tagged_date': None,
#    'tags_id': 48170044},
#   {'description': 'Media for which url sharing on twitter is aligned with the U.S. partisan center right',
#    'label': 'Tweeted Somewhat More by Followers of Conservative Politicians 2019 (US Center Right 2019)',
#    'media_id': 39872,
#    'show_on_media': True,
#    'show_on_stories': False,
#    'tag': 'Tweeted_Somewhat_More_by_Followers_of_Conservative_Politicians_2019__US_Center_Right_2019_',
#    'tag_set': 'twitter_partisanship',
#    'tag_sets_id': 15765109,
#    'tagged_date': '2020-06-04',
#    'tags_id': 200363062}],
#  'name': 'HindustanTimes',
#  'num_sentences_90': 8.1,
#  'num_stories_90': 0.33,
#  'public_notes': '',
#  'start_date': '2016-08-08',
#  'url': 'http://www.hindustantimes.com/',
#  'metadata': {'pub_country': {'description': 'Published in India',
#    'label': 'India',
#    'media_id': 39872,
#    'show_on_media': True,
#    'show_on_stories': None,
#    'tag': 'pub_IND',
#    'tag_set': 'pub_country',
#    'tag_sets_id': 1935,
#    'tagged_date': None,
#    'tags_id': 9353533},
#   'pub_state': {'description': 'Published in Delhi, India',
#    'label': 'Delhi, India',
#    'media_id': 39872,
#    'show_on_media': False,
#    'show_on_stories': False,
#    'tag': 'pub_IN-DL',
#    'tag_set': 'pub_state',
#    'tag_sets_id': 1962,
#    'tagged_date': None,
#    'tags_id': 38379958},
#   'language': {'description': 'Media sources for which the primary language is English',
#    'label': 'English',
#    'media_id': 39872,
#    'show_on_media': True,
#    'show_on_stories': None,
#    'tag': 'en',
#    'tag_set': 'primary_language',
#    'tag_sets_id': 1969,
#    'tagged_date': None,
#    'tags_id': 9361422},
#   'about_country': {'description': 'Media sources for which the majority subject country is Republic of India.',
#    'label': 'Republic of India',
#    'media_id': 39872,
#    'show_on_media': None,
#    'show_on_stories': None,
#    'tag': 'Republic of India',
#    'tag_set': 'subject_country',
#    'tag_sets_id': 1970,
#    'tagged_date': None,
#    'tags_id': 9361509},
#   'media_type': {'description': 'This source is primarly a print publication. Use this for newspapers and magazines. Examples: New York Times, The Economist.',
#    'label': 'Print Native',
#    'media_id': 39872,
#    'show_on_media': True,
#    'show_on_stories': None,
#    'tag': 'print_native',
#    'tag_set': 'media_format',
#    'tag_sets_id': 1972,
#    'tagged_date': None,
#    'tags_id': 32018491}}}

# %%
# list all the feeds associated with this media source
hindistan_times_feeds = mc.feedList(media_id=hindustan_times['media_id'], rows=200)
hindistan_times_feeds
# Out:
# [{'active': False,
#   'feeds_id': 130764,
#   'last_attempted_download_time': '2016-12-18 05:05:50.831552-05:00',
#   'last_new_story_time': '2015-09-16 20:28:37.564327-04:00',
#   'last_successful_download_time': '2015-10-11 12:26:20-04:00',
#   'media_id': 39872,
#   'name': 'News Stories - Hindustan Times',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/RSSFeed/News.aspx'},
#  {'active': False,
#   'feeds_id': 130765,
#   'last_attempted_download_time': '2016-12-18 05:05:50.831552-05:00',
#   'last_new_story_time': '2015-09-22 23:34:58.379944-04:00',
#   'last_successful_download_time': '2015-10-10 15:45:26-04:00',
#   'media_id': 39872,
#   'name': 'Latest India News Stories - Hindustan Times',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/RSSFeed/India.aspx'},
#  {'active': False,
#   'feeds_id': 130766,
#   'last_attempted_download_time': '2016-12-18 05:05:50.831552-05:00',
#   'last_new_story_time': '2015-09-23 07:36:05.052711-04:00',
#   'last_successful_download_time': '2015-10-10 23:16:13-04:00',
#   'media_id': 39872,
#   'name': 'Latest World News Stories - Hindustan Times',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/RSSFeed/World.aspx'},
#  {'active': False,
#   'feeds_id': 130767,
#   'last_attempted_download_time': '2016-12-17 20:04:17.491623-05:00',
#   'last_new_story_time': '2015-09-15 14:53:20.871544-04:00',
#   'last_successful_download_time': '2015-10-10 07:13:51-04:00',
#   'media_id': 39872,
#   'name': 'Top Editorial Comment - Hindustan Times',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/RSSFeed/Views.aspx'},
#  {'active': False,
#   'feeds_id': 130768,
#   'last_attempted_download_time': '2014-12-24 02:55:18.056748-05:00',
#   'last_new_story_time': '2013-07-24 07:01:59.186104-04:00',
#   'last_successful_download_time': None,
#   'media_id': 39872,
#   'name': 'Top Cinema News Stories - Hindustan Times',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/RSSFeed/cinema.aspx'},
#  {'active': False,
#   'feeds_id': 130769,
#   'last_attempted_download_time': '2016-12-18 05:05:50.831552-05:00',
#   'last_new_story_time': '2015-09-21 11:16:23.627060-04:00',
#   'last_successful_download_time': '2015-10-06 11:27:33-04:00',
#   'media_id': 39872,
#   'name': 'Top Cricket News Stories - Hindustan Times',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/RSSFeed/Cricket.aspx'},
#  {'active': False,
#   'feeds_id': 130770,
#   'last_attempted_download_time': '2016-12-18 05:05:50.831552-05:00',
#   'last_new_story_time': '2015-09-23 16:07:46.798199-04:00',
#   'last_successful_download_time': '2015-10-11 07:47:57-04:00',
#   'media_id': 39872,
#   'name': 'Top Business News Stories - Hindustan Times',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/RSSFeed/Business.aspx'},
#  {'active': False,
#   'feeds_id': 130771,
#   'last_attempted_download_time': '2016-12-18 05:05:50.831552-05:00',
#   'last_new_story_time': '2015-10-03 10:31:34.903053-04:00',
#   'last_successful_download_time': '2015-10-03 18:05:48-04:00',
#   'media_id': 39872,
#   'name': 'Top Lifestyle News Stories - Hindustan Times',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/RSSFeed/LifeStyle.aspx'},
#  {'active': False,
#   'feeds_id': 130772,
#   'last_attempted_download_time': '2014-12-24 02:55:18.056748-05:00',
#   'last_new_story_time': '2013-07-24 07:01:59.186104-04:00',
#   'last_successful_download_time': None,
#   'media_id': 39872,
#   'name': 'Top News Stories from India and World - Hindustan Times',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/RSSFeed/HomePage-TopStories.aspx'},
#  {'active': False,
#   'feeds_id': 130773,
#   'last_attempted_download_time': '2014-12-24 02:55:18.056748-05:00',
#   'last_new_story_time': '2013-07-24 07:01:59.186104-04:00',
#   'last_successful_download_time': None,
#   'media_id': 39872,
#   'name': 'Latest News Stories - Hindustan Times',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/RSSFeed/Common-Chunk-HT-UI-Common-LatestNews.aspx'},
#  {'active': False,
#   'feeds_id': 136195,
#   'last_attempted_download_time': '2018-09-02 12:54:03.042365-04:00',
#   'last_new_story_time': '2018-09-02 12:54:03.042365-04:00',
#   'last_successful_download_time': '2018-09-05 05:49:45-04:00',
#   'media_id': 39872,
#   'name': 'HindustanTimes',
#   'type': 'web_page',
#   'url': 'http://www.hindustantimes.com/'},
#  {'active': True,
#   'feeds_id': 422363,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-08 07:32:25.120616-05:00',
#   'last_successful_download_time': '2021-01-08 15:05:37.051669-05:00',
#   'media_id': 39872,
#   'name': 'HindustanTimes- Top news',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/topnews/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422364,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-08 12:03:47.434491-05:00',
#   'last_successful_download_time': '2021-01-08 15:35:50.905667-05:00',
#   'media_id': 39872,
#   'name': 'HindustanTimes- India',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/india/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422367,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2019-11-20 17:19:27.747449-05:00',
#   'last_successful_download_time': '2021-01-04 12:06:06.390749-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - auto',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/auto/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422368,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-07 13:56:31.311361-05:00',
#   'last_successful_download_time': '2021-01-08 05:32:24.844552-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - bhopal',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/cities/bhopal/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422369,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-08 10:03:02.832371-05:00',
#   'last_successful_download_time': '2021-01-08 17:36:41.849868-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - business',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/business/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422370,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-08 18:06:27.689029-05:00',
#   'last_successful_download_time': '2021-01-08 18:06:48.097273-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - chandigarh',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/cities/chandigarh/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422371,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-06 06:47:12.723291-05:00',
#   'last_successful_download_time': '2021-01-07 14:27:09.876557-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - dehradun',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/cities/dehradun/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422372,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-08 11:03:35.408735-05:00',
#   'last_successful_download_time': '2021-01-08 14:35:20.475834-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - delhi',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/cities/delhi/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422373,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-08 10:03:02.832371-05:00',
#   'last_successful_download_time': '2021-01-08 17:36:41.849868-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - education',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/education/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422374,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-08 11:33:41.590127-05:00',
#   'last_successful_download_time': '2021-01-08 15:05:37.051669-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - entertainment',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/entertainment/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422375,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-07 14:26:49.648145-05:00',
#   'last_successful_download_time': '2021-01-08 06:02:21.437701-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - gurgaon',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/cities/gurgaon/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422376,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': None,
#   'last_successful_download_time': '2021-01-03 02:26:55.052957-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - indepth',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/indepth/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422377,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2020-12-10 18:07:52.619224-05:00',
#   'last_successful_download_time': '2021-01-04 10:35:34.062782-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - indore',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/cities/indore/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422378,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-06 05:16:55.220023-05:00',
#   'last_successful_download_time': '2021-01-07 12:56:37.715188-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - jaipur',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/cities/jaipur/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422379,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-08 13:04:13.606903-05:00',
#   'last_successful_download_time': '2021-01-08 16:36:19.225877-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - kolkata',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/cities/kolkata/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422380,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-08 11:03:35.408735-05:00',
#   'last_successful_download_time': '2021-01-08 14:35:20.475834-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - lifestyle',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/lifestyle/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422381,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-08 12:34:05.462724-05:00',
#   'last_successful_download_time': '2021-01-08 16:06:04.307705-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - lucknow',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/cities/lucknow/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422382,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-08 15:05:17.232128-05:00',
#   'last_successful_download_time': '2021-01-08 16:36:19.225877-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - mumbai',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/cities/mumbai/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422383,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-07 13:56:31.311361-05:00',
#   'last_successful_download_time': '2021-01-08 05:32:24.844552-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - noida',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/cities/noida/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422384,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-07 11:25:42.972137-05:00',
#   'last_successful_download_time': '2021-01-08 03:01:30.161320-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - opinion',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/opinion/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422385,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-08 04:31:24.867634-05:00',
#   'last_successful_download_time': '2021-01-08 12:04:12.802741-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - patna',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/cities/patna/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422386,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-04 23:38:43.800188-05:00',
#   'last_successful_download_time': '2021-01-07 15:27:40.470444-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - ranchi',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/cities/ranchi/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422387,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-08 12:03:47.434491-05:00',
#   'last_successful_download_time': '2021-01-08 15:35:50.905667-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - sports',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/sports/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422388,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2020-05-08 23:36:32.203900-04:00',
#   'last_successful_download_time': '2021-01-06 00:15:24.112815-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - tech',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/tech/rssfeed.xml'},
#  {'active': True,
#   'feeds_id': 422389,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-01-08 13:34:24.318237-05:00',
#   'last_successful_download_time': '2021-01-08 17:06:28.559385-05:00',
#   'media_id': 39872,
#   'name': 'Hindustan Times  - world',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/rss/world/rssfeed.xml'},
#  {'active': False,
#   'feeds_id': 871840,
#   'last_attempted_download_time': '2018-09-06 13:04:12.403193-04:00',
#   'last_new_story_time': '2018-09-06 13:04:12.403193-04:00',
#   'last_successful_download_time': '2018-09-15 14:17:24-04:00',
#   'media_id': 39872,
#   'name': 'HindustanTimes',
#   'type': 'web_page',
#   'url': 'http://www.hindustantimes.com/interstitialad'},
#  {'active': False,
#   'feeds_id': 949881,
#   'last_attempted_download_time': None,
#   'last_new_story_time': None,
#   'last_successful_download_time': None,
#   'media_id': 39872,
#   'name': 'Spider Feed',
#   'type': 'syndicated',
#   'url': 'http://www.hindustantimes.com/'},
#  {'active': False,
#   'feeds_id': 1168376,
#   'last_attempted_download_time': '2018-09-06 13:04:12.403193-04:00',
#   'last_new_story_time': '2018-09-06 13:04:12.403193-04:00',
#   'last_successful_download_time': '2018-09-15 14:17:45-04:00',
#   'media_id': 39872,
#   'name': 'HindustanTimes',
#   'type': 'web_page',
#   'url': 'https://www.hindustantimes.com/interstitialad'},
#  {'active': True,
#   'feeds_id': 1184507,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2019-04-02 06:29:22.812161-04:00',
#   'last_successful_download_time': '2021-01-04 12:06:06.390749-05:00',
#   'media_id': 39872,
#   'name': 'Hindustantimes Feed',
#   'type': 'syndicated',
#   'url': 'https://www.hindustantimes.com/atom.xml'},
#  {'active': True,
#   'feeds_id': 2345061,
#   'last_attempted_download_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_new_story_time': '2021-11-30 17:19:51.969278-05:00',
#   'last_successful_download_time': '2021-11-30 17:20:16.959657-05:00',
#   'media_id': 39872,
#   'name': 'HindustanTimes',
#   'type': 'web_page',
#   'url': 'https://www.hindustantimes.com/'}]

# %%
# but only some of these are active ones that we ingest news from every day
active_feeds = [f for f in hindistan_times_feeds if f['active']]
"{}/{} of the feeds are checked for new stories each day".format(len(active_feeds), len(hindistan_times_feeds))
# Out:
# '27/41 of the feeds are checked for new stories each day'

# %%
# fetch all the feeds and dump to a csv
def all_source_feeds(media_id):
    more_feeds = True
    last_feeds_id = None
    all_feeds = []
    while more_feeds:
        feed_page = mc.feedList(media_id, last_feeds_id=last_feeds_id, rows=100)
        print("  fetched a page of {} feeeds".format(len(feed_page)))
        if len(feed_page) == 0:
            more_feeds = False
        else:
            all_feeds += feed_page
            last_feeds_id = feed_page[-1]['feeds_id']
    return all_feeds
all_hindistan_times_feeds = all_source_feeds(media_id=hindustan_times['media_id'])
# dump to CSV
fieldnames = ['feeds_id', 'active', 'type', 'media_id', 'name', 'url']
filename = 'media-{}-feeds.csv'.format(hindustan_times['media_id'])
with open(filename, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames, extrasaction='ignore')
    writer.writeheader()
    for s in all_hindistan_times_feeds:
        writer.writerow(s)
print("Wrote {} feeds to {}".format(len(all_hindistan_times_feeds), filename))
# Out:
#   fetched a page of 41 feeeds
#   fetched a page of 0 feeeds
# Wrote 41 feeds to media-39872-feeds.csv

# %% [markdown]
# ## Collections
# Media Sources are grouped together into collections. These are implement internally as `tags`. Collections are grouped together as `tag_sets` for convenience of internal system operations. This can be confusing to navigate as humans. We have tons of collections, but the geographic ones the most useful place to start investigating things.

# %%
# all the geographic collections were seeeded from http://www.abyznewslinks.com in 2018; since then we have cleaned and augmented them
GEOGRAPHIC_COLLECTIONS_TAG_SET = 15765102
mc.tagSet(GEOGRAPHIC_COLLECTIONS_TAG_SET)
# Out:
# {'description': 'Tags in this set indicate that the media source covers a certain geographic area',
#  'label': 'Geographic Collections',
#  'name': 'geographic_collection',
#  'show_on_media': False,
#  'show_on_stories': False,
#  'tag_sets_id': 15765102}

# %%
# list the collections in this tag set
geographic_collections = mc.tagList(tag_sets_id=GEOGRAPHIC_COLLECTIONS_TAG_SET)
[c['label'] for c in geographic_collections]
# Out:
# ['Canada - National',
#  'Saint Martin (French part) - National',
#  'Sao Tome and Principe - National',
#  'Cambodia - National',
#  'Switzerland - National',
#  'Ethiopia - National',
#  'Aruba - National',
#  'Swaziland - National',
#  'Svalbard and Jan Mayen - National',
#  'Congo, The Democratic Republic of the - National',
#  'Argentina - National',
#  'Bolivia, Plurinational State of - National',
#  'Burkina Faso - National',
#  'Bahrain - National',
#  'Saudi Arabia - National',
#  'Rwanda - National',
#  'South Georgia and the South Sandwich Islands - National',
#  'Japan - National',
#  'American Samoa - National',
#  'Northern Mariana Islands - National']

# %%
# page through a list of all of the collections in this tag_set, using the `last_tags_id` parameter
def all_tags_in_tag_set(tag_sets_id):
    more_tags = True
    last_tags_id = None
    all_tags = []
    while more_tags:
        tag_page = mc.tagList(tag_sets_id=tag_sets_id, rows=500, last_tags_id=last_tags_id)
        print("  got a page of {} tags".format(len(tag_page)))
        if len(tag_page) == 0:
            more_tags = False
        else:
            all_tags += tag_page
            last_tags_id = tag_page[-1]['tags_id']
    return all_tags

all_geographic_collections = all_tags_in_tag_set(GEOGRAPHIC_COLLECTIONS_TAG_SET)
"Found {} total geographic collections".format(len(all_geographic_collections))
# Out:
#   got a page of 500 tags
#   got a page of 500 tags
#   got a page of 500 tags
#   got a page of 37 tags
#   got a page of 0 tags
# 'Found 1537 total geographic collections'

# %%
# this isn't encoded into a heirarchy, but there are some conventions here:
# 1. each country's national and state/local collections start with the country name
# 2. each country's province/state level collections include their alpha2 name
# for instance, this finds all the collections related to Spain
spain_collections = [c for c in all_geographic_collections if c['label'] and (c['label'].startswith('Spain') or c['tag'].startswith('geo_ES-'))]
[c['label'] for c in spain_collections]
# Out:
# ['Spain - National',
#  'Spain - State & Local',
#  'Madrid, Spain - State & Local',
#  'Andalucía, Spain - State & Local',
#  'Aragón, Spain - State & Local',
#  'Asturias, Principado de, Spain - State & Local',
#  'Illes Balears, Spain - State & Local',
#  'Canarias, Spain - State & Local',
#  'Cantabria, Spain - State & Local',
#  'Castilla-La Mancha, Spain - State & Local',
#  'Castilla y León, Spain - State & Local',
#  'Catalunya, Spain - State & Local',
#  'Ceuta, Spain - State & Local',
#  'Extremadura, Spain - State & Local',
#  'Galicia, Spain - State & Local',
#  'La Rioja, Spain - State & Local',
#  'Melilla, Spain - State & Local',
#  'Murcia, Spain - State & Local',
#  'Navarra / Nafarroa, Spain - State & Local',
#  'País Vasco / Euskal Herria, Spain - State & Local',
#  'Valenciana, Comunidad / Valenciana, Comunitat, Spain - State & Local']

# %% [markdown]
# ## Reference: Media Source Metadata Tags
# Here is a quick utility to let you generate a list of all the values possible for each type of media metadata (aka the `tags` in each media metadata `tag_set`). These constants are available in `mediacloud.tags`

# %%
fieldnames = ['tags_id', 'label', 'tag', 'description']
for metadata_tag_sets_id in mediacloud.tags.METADATA_TAG_SETS:
    tag_set = mc.tagSet(metadata_tag_sets_id)
    print("{}:".format(tag_set['label']))
    tags_in_set = all_tags_in_tag_set(metadata_tag_sets_id)
    filename = 'metadata-{}-tags.csv'.format(tag_set['name'])
    with open(filename, 'w', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames, extrasaction='ignore')
        writer.writeheader()
        for s in tags_in_set:
            writer.writerow(s)
    print("  Wrote {} tags to {}".format(len(tags_in_set), filename))
# Out:
# Publication Country:
#   got a page of 245 tags
#   got a page of 0 tags
#   Wrote 245 tags to metadata-pub_country-tags.csv
# Publication State:
#   got a page of 500 tags
#   got a page of 500 tags
#   got a page of 190 tags
#   got a page of 0 tags
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-26-26d43c67ce09> in <module>
#       9         writer.writeheader()
#      10         for s in tags_in_set:
# ---> 11             writer.writerow(s)
#      12     print("  Wrote {} tags to {}".format(len(tags_in_set), filename))
#
# C:\ProgramData\Anaconda3\lib\csv.py in writerow(self, rowdict)
#     152
#     153     def writerow(self, rowdict):
# --> 154         return self.writer.writerow(self._dict_to_list(rowdict))
#     155
#     156     def writerows(self, rowdicts):
#
# C:\ProgramData\Anaconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u010d' in position 12: character maps to <undefined>
