# %% [markdown]
# # Get data from The New York Times
#
# Thanks https://towardsdatascience.com/collecting-data-from-the-new-york-times-over-any-period-of-time-3e365504004
#
# ## First, get a NYT API key:
#
#
# Create a free developer’s account here. Sign in after you open the link in the verification email. Make your way to the developer’s home page.
#
#
# In this notebook, we set up the functions to send and process multiple queries to the Article Search API provided by The New York Times. Each query asks for articles that contain a deaf-related phrase, such as "deaf and dumb" or "hearing-impaired". Full list of phrases below.
#
# The Article Search API returns a max of 10 results at a time. If we got 143 hits. The current offset is 0, so this means we are on the first 10 results, or the first page. If we append `&page=2` to the query, and process that response, now the offset is 10. This confirms we are on the second page. Since each page has 10 results and we have 143 hits, we will need to go through ceil(143/10) = 15 pages to get all of them.
#
# Contents:
# - Define functions
# - Set up queries
# - Get data
# - Postprocessing
#
# Import dependencies.

# %%
import os
import dateutil
import pandas as pd
#pd.options.display.max_colwidth = 100
import numpy as np
import requests
import time
import json
from ast import literal_eval
import datetime
from dateutil.relativedelta import relativedelta

key=""

# %% [markdown]
# ## Define functions

# %%
def send_request(query, page):
    '''Sends a request to the NYT Archive API for given date.'''
    base_url = 'http://api.nytimes.com/svc/search/v2/articlesearch.json'
    url = base_url + '?fq=' + query + '&api-key=' + key + '&page=' + str(page)
    response = requests.get(url).json()
    time.sleep(6)
    return response


def parse_response(response, data):
    '''Parses and returns response as pandas data frame.'''
    
    articles = response['response']['docs'] 
    for article in articles: 
        
        # id
        data['id'].append(article['_id'])
        
        # Date
        date = dateutil.parser.parse(article['pub_date']).date()
        data['date'].append(date)
        
        # Headline
        data['headline'].append(article['headline']['main']) 
        
        # Section
        if 'section_name' in article:
            data['section'].append(article['section_name'])
        else:
            data['section'].append(None)
        
        # News desk
        if 'news_desk' in article:
            data['news_desk'].append(article['news_desk'])
        else:
            data['news_desk'].append(None)
        
        # Document type
        data['doc_type'].append(article['document_type'])
        
        # Type of material
        if 'type_of_material' in article: 
            data['material_type'].append(article['type_of_material'])
        else:
            data['material_type'].append(None)
            
        # Keywords
        keywords = [keyword['value'] for keyword in article['keywords'] if keyword['name'] == 'subject']
        data['keywords'].append(keywords)
        
        # Web URL
        if 'web_url' in article:
            data['url'].append(article['web_url'])
            
        # Author
        if 'byline' in article:
            data['byline'].append(article['byline']['original'])
        else:
            data['byline'].append(None)
            
            
def send_query(query, data, date=None):
    # If the query has already been sent, don't send again
    if query + '.csv' in os.listdir('data'): 
        print('Already have data for the term "' + query + '".\n')
        return False
    
    # If date is provided, append to query string
    query_str = queries[query]
    if date:
        query_str = query_str + date
        
    print('Querying string: ' + query_str + '\n')
    
    page_num = 0
    while True:
        response = send_request(query_str, page_num)
        offset = response['response']['meta']['offset']
        hits = response['response']['meta']['hits']
        
        if offset > hits: 
            print('Done processing results.\n')
            return True
        # If we have 2,000 hits or more, we will need to break down our query into date intervals
        elif hits >= 2000: 
            print('We have over 2,000 hits.\n')
            # Send the same query again, once for each date interval
            for date in q_dates:
                send_query(query, data, date) 
            return True
            
        print('Processing results ' + str(offset) + '—' + str(min((offset + 10), hits)) + '/' + str(hits) + '...')
        parse_response(response, data)
        page_num += 1

# %% [markdown]
# ## Set up queries

# %% [markdown]
# Our goal is to analyze the usage of deaf-related terms in *The New York Times*.
#
# The deaf-related terms:
#
# - "deaf and dumb"
# - "deaf-mute"
# - "hearing-impaired"
# - "tone deaf"
# - "deaf as a post"
# - "stone deaf"
# - "fell on deaf ears"
# - "deaf" (excluding its presence in all of the above terms)
#
# Some terms have varieties. For example, take "fell on deaf ears." Taking into consideration all of its varieties (that yielded hits when testing manually), the resulting query would be
#
# >`body:"fell on deaf ears" OR headline:"fell on deaf ears"
# OR body:"fall on deaf ears" OR headline:"fall on deaf ears"
# OR body:"falls on deaf ears"
# OR body:"fall on a deaf ear"
# OR body:"fell on a deaf ear"
# OR body:"turn a deaf ear" OR headline:"turn a deaf ear"
# OR body:"turned deaf ear" OR headline:"turned deaf ear"
# OR body:"turned a deaf ear" OR headline:"turned a deaf ear"`
#
# Construct remaining queries. I did this by checking the API manually in the browser, adding conditions one by one.
#
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq= + `query` + &api-key= + `key`

# %%
deaf_and_dumb = ['deaf and dumb',
                 'deaf dumb']

deaf_mute = ['deaf mute',
             'deaf and mute',
             'mute deaf',
             'mute and deaf']

fell_on_deaf_ears = ['fell on deaf ears', 
                     'fall on deaf ears', 
                     'falls on deaf ears', 
                     'fall on a deaf ear',
                     'falling on deaf ears',
                     'falling on a deaf ear',
                     'turn a deaf ear', 
                     'turned deaf ears', 
                     'turned a deaf ear',
                     'turning deaf ears',
                     'turning a deaf ear']

hearing_impaired = ['hearing impaired', 
                    'hearing impairment']

tone_deaf = ['tone deaf']

deaf_as_a_post = ['deaf as a post']

stone_deaf = ['stone deaf']

deaf = ['deaf']

# %%
phrases = {'deaf_and_dumb': deaf_and_dumb,
           'deaf_mute': deaf_mute,
           'fell_on_deaf_ears': fell_on_deaf_ears,
           'hearing_impaired': hearing_impaired,
           'tone_deaf': tone_deaf,
           'deaf_as_a_post': deaf_as_a_post,
           'stone_deaf': stone_deaf,
           'deaf': deaf}

# Save phrases to file
with open('phrases.txt', 'w') as outfile:
    json.dump(phrases, outfile)

# %% [markdown]
# Construct queries based on phrases.

# %%
queries = {phrase: (' OR ').join(['body:"' + x + '" OR headline:"' + x + '"' for x in phrases[phrase]]) for phrase in phrases.keys()}

# Edit 'deaf' query to exclude all other phrases that contain 'deaf'
queries['deaf'] = '(' + queries['deaf'] + ') AND NOT (' + queries['deaf_and_dumb'] \
+ ') AND NOT (' + queries['deaf_mute'] + ') AND NOT (' + queries['fell_on_deaf_ears'] \
+ ') AND NOT (' + queries['tone_deaf'] + ') AND NOT (' + queries['deaf_as_a_post'] \
+ ') AND NOT (' + queries['stone_deaf'] + ')'

queries
# Out:
# {'deaf_and_dumb': 'body:"deaf and dumb" OR headline:"deaf and dumb" OR body:"deaf dumb" OR headline:"deaf dumb"',
#  'deaf_mute': 'body:"deaf mute" OR headline:"deaf mute" OR body:"deaf and mute" OR headline:"deaf and mute" OR body:"mute deaf" OR headline:"mute deaf" OR body:"mute and deaf" OR headline:"mute and deaf"',
#  'fell_on_deaf_ears': 'body:"fell on deaf ears" OR headline:"fell on deaf ears" OR body:"fall on deaf ears" OR headline:"fall on deaf ears" OR body:"falls on deaf ears" OR headline:"falls on deaf ears" OR body:"fall on a deaf ear" OR headline:"fall on a deaf ear" OR body:"falling on deaf ears" OR headline:"falling on deaf ears" OR body:"falling on a deaf ear" OR headline:"falling on a deaf ear" OR body:"turn a deaf ear" OR headline:"turn a deaf ear" OR body:"turned deaf ears" OR headline:"turned deaf ears" OR body:"turned a deaf ear" OR headline:"turned a deaf ear" OR body:"turning deaf ears" OR headline:"turning deaf ears" OR body:"turning a deaf ear" OR headline:"turning a deaf ear"',
#  'hearing_impaired': 'body:"hearing impaired" OR headline:"hearing impaired" OR body:"hearing impairment" OR headline:"hearing impairment"',
#  'tone_deaf': 'body:"tone deaf" OR headline:"tone deaf"',
#  'deaf_as_a_post': 'body:"deaf as a post" OR headline:"deaf as a post"',
#  'stone_deaf': 'body:"stone deaf" OR headline:"stone deaf"',
#  'deaf': '(body:"deaf" OR headline:"deaf") AND NOT (body:"deaf and dumb" OR headline:"deaf and dumb" OR body:"deaf dumb" OR headline:"deaf dumb") AND NOT (body:"deaf mute" OR headline:"deaf mute" OR body:"deaf and mute" OR headline:"deaf and mute" OR body:"mute deaf" OR headline:"mute deaf" OR body:"mute and deaf" OR headline:"mute and deaf") AND NOT (body:"fell on deaf ears" OR headline:"fell on deaf ears" OR body:"fall on deaf ears" OR headline:"fall on deaf ears" OR body:"falls on deaf ears" OR headline:"falls on deaf ears" OR body:"fall on a deaf ear" OR headline:"fall on a deaf ear" OR body:"falling on deaf ears" OR headline:"falling on deaf ears" OR body:"falling on a deaf ear" OR headline:"falling on a deaf ear" OR body:"turn a deaf ear" OR headline:"turn a deaf ear" OR body:"turned deaf ears" OR headline:"turned deaf ears" OR body:"turned a deaf ear" OR headline:"turned a deaf ear" OR body:"turning deaf ears" OR headline:"turning deaf ears" OR body:"turning a deaf ear" OR headline:"turning a deaf ear") AND NOT (body:"tone deaf" OR headline:"tone deaf") AND NOT (body:"deaf as a post" OR headline:"deaf as a post") AND NOT (body:"stone deaf" OR headline:"stone deaf")'}

# %% [markdown]
# ## Get data

# %% [markdown]
# Date intervals for NYT search API are formatted as `&begin_date=20120101&end_date=20121231`. We need to format date intervals because if our query returns over 2,000 results, we can't get them all. We need to make our query smaller, and we can do that by narrowing the date interval. We will do 5-year intervals.

# %%
start, end = [datetime.datetime.strptime("1850-01-01", "%Y-%m-%d"), datetime.datetime.today()]
interval = 5 # years
dates = [(start + relativedelta(years=x)).strftime('%Y%m%d') for x in range(0, relativedelta(end, start).years + 10, interval)]
q_dates = ['&begin_date=' + start + '&end_date=' + end for start, end in zip(dates, dates[1:])]

# %% [markdown]
# Send these queries to the Archive API to create CSV tables that we save to `./data/`.

# %%
for query in list(queries.keys()):
    # Reset the global data object
    data = {'headline': [],  
            'date': [], 
            'doc_type': [],
            'material_type': [],
            'news_desk': [],
            'section': [],
            'keywords': [],
            'url': [],
            'id': [],
            'byline': []}
    
    # Send query
    got_result = send_query(query, data)
    
    # Build and save frame from data object 
    if got_result:
        data_df = pd.DataFrame(data)
        data_df['date'] = pd.to_datetime(data_df['date'])
        data_df.to_csv('data/' + query + '.csv', index=False)
        print('Saved as ' + query + '.csv.\n')
# Out:
# Already have data for the term "deaf_and_dumb".
#
# Already have data for the term "deaf_mute".
#
# Querying string: body:"fell on deaf ears" OR headline:"fell on deaf ears" OR body:"fall on deaf ears" OR headline:"fall on deaf ears" OR body:"falls on deaf ears" OR headline:"falls on deaf ears" OR body:"fall on a deaf ear" OR headline:"fall on a deaf ear" OR body:"falling on deaf ears" OR headline:"falling on deaf ears" OR body:"falling on a deaf ear" OR headline:"falling on a deaf ear" OR body:"turn a deaf ear" OR headline:"turn a deaf ear" OR body:"turned deaf ears" OR headline:"turned deaf ears" OR body:"turned a deaf ear" OR headline:"turned a deaf ear" OR body:"turning deaf ears" OR headline:"turning deaf ears" OR body:"turning a deaf ear" OR headline:"turning a deaf ear"
#
# Processing results 0—10/1757...
# Processing results 10—20/1757...
# Processing results 20—30/1757...
# Processing results 30—40/1757...
# Processing results 40—50/1757...
# Processing results 50—60/1757...
# Processing results 60—70/1757...
# Processing results 70—80/1757...
# Processing results 80—90/1757...
# Processing results 90—100/1757...
# Processing results 100—110/1757...
# Processing results 110—120/1757...
# Processing results 120—130/1757...
# Processing results 130—140/1757...
# Processing results 140—150/1757...
# Processing results 150—160/1757...
# Processing results 160—170/1757...
# Processing results 170—180/1757...
# Processing results 180—190/1757...
# Processing results 190—200/1757...
# Processing results 200—210/1757...
# Processing results 210—220/1757...
# Processing results 220—230/1757...
# Processing results 230—240/1757...
# Processing results 240—250/1757...
# Processing results 250—260/1757...
# Processing results 260—270/1757...
# Processing results 270—280/1757...
# Processing results 280—290/1757...
# Processing results 290—300/1757...
# Processing results 300—310/1757...
# Processing results 310—320/1757...
# Processing results 320—330/1757...
# Processing results 330—340/1757...
# Processing results 340—350/1757...
# Processing results 350—360/1757...
# Processing results 360—370/1757...
# Processing results 370—380/1757...
# Processing results 380—390/1757...
# Processing results 390—400/1757...
# Processing results 400—410/1757...
# Processing results 410—420/1757...
# Processing results 420—430/1757...
# Processing results 430—440/1757...
# Processing results 440—450/1757...
# Processing results 450—460/1757...
# Processing results 460—470/1757...
# Processing results 470—480/1757...
# Processing results 480—490/1757...
# Processing results 490—500/1757...
# Processing results 500—510/1757...
# Processing results 510—520/1757...
# Processing results 520—530/1757...
# Processing results 470—480/876...
# Processing results 480—490/876...
# Processing results 490—500/876...
# Processing results 500—510/876...
# Processing results 510—520/876...
# Processing results 520—530/876...
# Processing results 530—540/876...
# Processing results 540—550/876...
# Processing results 550—560/876...
# Processing results 560—570/876...
# Processing results 570—580/876...
# Processing results 580—590/876...
# Processing results 590—600/876...
# Processing results 600—610/876...
# Processing results 610—620/876...
# Processing results 620—630/876...
# Processing results 630—640/876...
# Processing results 640—650/876...
# Processing results 650—660/876...
# Processing results 660—670/876...
# Processing results 670—680/876...
# Processing results 680—690/876...
# Processing results 690—700/876...
# Processing results 700—710/876...
# Processing results 710—720/876...
# Processing results 720—730/876...
# Processing results 730—740/876...
# Processing results 740—750/876...
# Processing results 750—760/876...
# Processing results 760—770/876...
# Processing results 770—780/876...
# Processing results 780—790/876...
# Processing results 790—800/876...
# Processing results 800—810/876...
# Processing results 810—820/876...
# Processing results 820—830/876...
# Processing results 830—840/876...
# Processing results 840—850/876...
# Processing results 850—860/876...
# Processing results 860—870/876...
# Processing results 870—876/876...
# Done processing results.
#
# Querying string: (body:"deaf" OR headline:"deaf") AND NOT (body:"deaf and dumb" OR headline:"deaf and dumb" OR body:"deaf dumb" OR headline:"deaf dumb") AND NOT (body:"deaf mute" OR headline:"deaf mute" OR body:"deaf and mute" OR headline:"deaf and mute" OR body:"mute deaf" OR headline:"mute deaf" OR body:"mute and deaf" OR headline:"mute and deaf") AND NOT (body:"fell on deaf ears" OR headline:"fell on deaf ears" OR body:"fall on deaf ears" OR headline:"fall on deaf ears" OR body:"falls on deaf ears" OR headline:"falls on deaf ears" OR body:"fall on a deaf ear" OR headline:"fall on a deaf ear" OR body:"falling on deaf ears" OR headline:"falling on deaf ears" OR body:"falling on a deaf ear" OR headline:"falling on a deaf ear" OR body:"turn a deaf ear" OR headline:"turn a deaf ear" OR body:"turned deaf ears" OR headline:"turned deaf ears" OR body:"turned a deaf ear" OR headline:"turned a deaf ear" OR body:"turning deaf ears" OR headline:"turning deaf ears" OR body:"turning a deaf ear" OR headline:"turning a deaf ear") AND NOT (body:"tone deaf" OR headline:"tone deaf") AND NOT (body:"deaf as a post" OR headline:"deaf as a post") AND NOT (body:"stone deaf" OR headline:"stone deaf")&begin_date=20200101&end_date=20250101
#
# Processing results 0—10/121...
# Processing results 10—20/121...
# Processing results 20—30/121...
# Processing results 30—40/121...
# Processing results 40—50/121...
# Processing results 50—60/121...
# Processing results 60—70/121...
# Processing results 70—80/121...
# Processing results 80—90/121...
# Processing results 90—100/121...
# Processing results 100—110/121...
# Processing results 110—120/121...
# Processing results 120—121/121...
# Done processing results.
#
# Saved as deaf.csv.

# %% [markdown]
# Merge all dataframes into one, with True or False for whether they contain a particular phrase. This means we're setting these additional `bool` columns:
#
# - deaf_and_dumb
# - deaf_mute
# - fall_on_deaf_ears
# - hearing_impaired
# - tone_deaf
# - deaf_as_a_post
# - stone_deaf
# - deaf

# %%
final_df = pd.DataFrame(columns=data.keys())

# For each key
for key in queries.keys():
    # Read in its CSV
    df = pd.read_csv('data/' + key + '.csv')
    
    # Drop any duplicates for this term alone
    num_dupes = len(df[df['id'].duplicated()])
    if num_dupes > 0:
        print('Dropping duplicates: ' + str(num_dupes))
        df = df.drop_duplicates(subset='id')
    print('added to final_df the df for key ' + key + ' with ' + str(len(df)) + ' values')
    
    df[key] = True # Label each row of this df as belonging to that df
    final_df = pd.concat([final_df, df], axis=0) # Add the df to the final df
    final_df.reset_index(drop=True, inplace=True)

print('\nTotal values: ' + str(len(final_df)))
# Out:
# added to final_df the df for key deaf_and_dumb with 727 values
# added to final_df the df for key deaf_mute with 1120 values
# added to final_df the df for key fell_on_deaf_ears with 1757 values
# added to final_df the df for key hearing_impaired with 1302 values
# added to final_df the df for key tone_deaf with 1739 values
# added to final_df the df for key deaf_as_a_post with 22 values
# added to final_df the df for key stone_deaf with 65 values
# Dropping duplicates: 8
# added to final_df the df for key deaf with 11331 values
#
# Total values: 18063

# %%
final_df
# Out:
#                                                 headline        date  \
# 0                              THE DEAF AND DUMB WAITER.  1885-12-03
# 1              Chad Threatens to Expel Sudanese Refugees  2006-04-14
# 2                WELFARE HOTEL CHILDREN: TOMORROW'S POOR  1987-07-16
# 3      Wal-Mart Says Oil Prices Held Down Profits for...  2005-08-16
# 4       A Space Force? The Idea May Have Merit, Some Say  2018-06-23
# ...                                                  ...         ...
# 18058                                       Alexa, Awake  2020-01-03
# 18059                    Confessions of a Dating Profile  2020-01-03
# 18060                   How to Make Billions in E-Sports  2020-02-19
# 18061                         Parent-Teacher Association  2020-01-03
# 18062  How Architecture Could Help Us Adapt to the Pa...  2020-06-10
#
#          doc_type        material_type          news_desk       section  \
# 0         article             Archives               None      Archives
# 1         article                 News      International         World
# 2         article                 News  Metropolitan Desk      New York
# 3         article                 News           Business  Business Day
# 4         article                 News         Washington          U.S.
# ...           ...                  ...                ...           ...
# 18058  multimedia  Interactive Feature            Opinion       Opinion
# 18059  multimedia  Interactive Feature            Opinion       Opinion
# 18060  multimedia  Interactive Feature           Magazine      Magazine
# 18061  multimedia  Interactive Feature            Opinion       Opinion
# 18062  multimedia  Interactive Feature           Magazine      Magazine
#
#                                                 keywords  \
# 0                                                     []
# 1                                                     []
# 2      ['Homeless Persons', 'HOTELS AND MOTELS', 'Chi...
# 3                                    ['Company Reports']
# 4      ['Space and Astronomy', 'United States Defense...
# ...                                                  ...
# 18058              ['Privacy', 'Science and Technology']
# 18059  ['Artificial Intelligence', 'Dating and Relati...
# 18060  ['E-Sports', 'Computer and Video Games', 'Fash...
# 18061  ['Privacy', 'Education (K-12)', 'Children and ...
# 18062  ['Coronavirus (2019-nCoV)', 'Workplace Environ...
#
#                                                      url  \
# 0      https://www.nytimes.com/1885/12/03/archives/th...
# 1      https://www.nytimes.com/2006/04/14/world/chad-...
# 2      https://www.nytimes.com/1987/07/16/nyregion/we...
# 3      https://www.nytimes.com/2005/08/16/business/wa...
# 4      https://www.nytimes.com/2018/06/23/us/politics...
# ...                                                  ...
# 18058  https://www.nytimes.com/interactive/2020/01/03...
# 18059  https://www.nytimes.com/interactive/2020/01/03...
# 18060  https://www.nytimes.com/interactive/2020/02/18...
# 18061  https://www.nytimes.com/interactive/2020/01/03...
# 18062  https://www.nytimes.com/interactive/2020/06/09...
#
#                                                       id             byline  \
# 0      nyt://article/0074c23c-1ff6-5bc7-85d9-e56a5af3...                NaN
# 1      nyt://article/00bb19d7-2ba6-5072-8e6b-3159730d...      By Marc Lacey
# 2      nyt://article/01670df3-ae07-5eb6-8862-7bd834bf...    By Lydia Chavez
# 3      nyt://article/0175ac61-cc62-5cdc-923c-f5efb8ec...    By Roben Farzad
# 4      nyt://article/01b8b8a5-7d0c-592a-a283-a9ccd3d8...   By Helene Cooper
# ...                                                  ...                ...
# 18058  nyt://interactive/c104e18e-f797-5490-b03c-259b...    By Brian Turner
# 18059  nyt://interactive/ccaba5b4-672d-568b-9daa-b6bb...     By Eric Kaplan
# 18060  nyt://interactive/dd0dfee2-c9c6-5f58-acde-0801...    By Robert Capps
# 18061  nyt://interactive/df6cd908-52b0-5851-ac81-e7b8...  By Jessica Powell
# 18062  nyt://interactive/e6694730-c72a-5173-ab0c-42d4...     By Kim Tingley
#
#       deaf_and_dumb deaf_mute fell_on_deaf_ears hearing_impaired tone_deaf  \
# 0              True       NaN               NaN              NaN       NaN
# 1              True       NaN               NaN              NaN       NaN
# 2              True       NaN               NaN              NaN       NaN
# 3              True       NaN               NaN              NaN       NaN
# 4              True       NaN               NaN              NaN       NaN
# ...             ...       ...               ...              ...       ...
# 18058           NaN       NaN               NaN              NaN       NaN
# 18059           NaN       NaN               NaN              NaN       NaN
# 18060           NaN       NaN               NaN              NaN       NaN
# 18061           NaN       NaN               NaN              NaN       NaN
# 18062           NaN       NaN               NaN              NaN       NaN
#
#       deaf_as_a_post stone_deaf  deaf
# 0                NaN        NaN   NaN
# 1                NaN        NaN   NaN
# 2                NaN        NaN   NaN
# 3                NaN        NaN   NaN
# 4                NaN        NaN   NaN
# ...              ...        ...   ...
# 18058            NaN        NaN  True
# 18059            NaN        NaN  True
# 18060            NaN        NaN  True
# 18061            NaN        NaN  True
# 18062            NaN        NaN  True
#
# [18063 rows x 18 columns]

# %% [markdown]
# ## Postprocessing

# %% [markdown]
# Go back through each key's column and set `NaN` to `False`.

# %%
for key in queries.keys():
    final_df[key].fillna(False, inplace=True)
final_df
# Out:
#                                                 headline        date  \
# 0                              THE DEAF AND DUMB WAITER.  1885-12-03
# 1              Chad Threatens to Expel Sudanese Refugees  2006-04-14
# 2                WELFARE HOTEL CHILDREN: TOMORROW'S POOR  1987-07-16
# 3      Wal-Mart Says Oil Prices Held Down Profits for...  2005-08-16
# 4       A Space Force? The Idea May Have Merit, Some Say  2018-06-23
# ...                                                  ...         ...
# 18058                                       Alexa, Awake  2020-01-03
# 18059                    Confessions of a Dating Profile  2020-01-03
# 18060                   How to Make Billions in E-Sports  2020-02-19
# 18061                         Parent-Teacher Association  2020-01-03
# 18062  How Architecture Could Help Us Adapt to the Pa...  2020-06-10
#
#          doc_type        material_type          news_desk       section  \
# 0         article             Archives               None      Archives
# 1         article                 News      International         World
# 2         article                 News  Metropolitan Desk      New York
# 3         article                 News           Business  Business Day
# 4         article                 News         Washington          U.S.
# ...           ...                  ...                ...           ...
# 18058  multimedia  Interactive Feature            Opinion       Opinion
# 18059  multimedia  Interactive Feature            Opinion       Opinion
# 18060  multimedia  Interactive Feature           Magazine      Magazine
# 18061  multimedia  Interactive Feature            Opinion       Opinion
# 18062  multimedia  Interactive Feature           Magazine      Magazine
#
#                                                 keywords  \
# 0                                                     []
# 1                                                     []
# 2      ['Homeless Persons', 'HOTELS AND MOTELS', 'Chi...
# 3                                    ['Company Reports']
# 4      ['Space and Astronomy', 'United States Defense...
# ...                                                  ...
# 18058              ['Privacy', 'Science and Technology']
# 18059  ['Artificial Intelligence', 'Dating and Relati...
# 18060  ['E-Sports', 'Computer and Video Games', 'Fash...
# 18061  ['Privacy', 'Education (K-12)', 'Children and ...
# 18062  ['Coronavirus (2019-nCoV)', 'Workplace Environ...
#
#                                                      url  \
# 0      https://www.nytimes.com/1885/12/03/archives/th...
# 1      https://www.nytimes.com/2006/04/14/world/chad-...
# 2      https://www.nytimes.com/1987/07/16/nyregion/we...
# 3      https://www.nytimes.com/2005/08/16/business/wa...
# 4      https://www.nytimes.com/2018/06/23/us/politics...
# ...                                                  ...
# 18058  https://www.nytimes.com/interactive/2020/01/03...
# 18059  https://www.nytimes.com/interactive/2020/01/03...
# 18060  https://www.nytimes.com/interactive/2020/02/18...
# 18061  https://www.nytimes.com/interactive/2020/01/03...
# 18062  https://www.nytimes.com/interactive/2020/06/09...
#
#                                                       id             byline  \
# 0      nyt://article/0074c23c-1ff6-5bc7-85d9-e56a5af3...                NaN
# 1      nyt://article/00bb19d7-2ba6-5072-8e6b-3159730d...      By Marc Lacey
# 2      nyt://article/01670df3-ae07-5eb6-8862-7bd834bf...    By Lydia Chavez
# 3      nyt://article/0175ac61-cc62-5cdc-923c-f5efb8ec...    By Roben Farzad
# 4      nyt://article/01b8b8a5-7d0c-592a-a283-a9ccd3d8...   By Helene Cooper
# ...                                                  ...                ...
# 18058  nyt://interactive/c104e18e-f797-5490-b03c-259b...    By Brian Turner
# 18059  nyt://interactive/ccaba5b4-672d-568b-9daa-b6bb...     By Eric Kaplan
# 18060  nyt://interactive/dd0dfee2-c9c6-5f58-acde-0801...    By Robert Capps
# 18061  nyt://interactive/df6cd908-52b0-5851-ac81-e7b8...  By Jessica Powell
# 18062  nyt://interactive/e6694730-c72a-5173-ab0c-42d4...     By Kim Tingley
#
#        deaf_and_dumb  deaf_mute  fell_on_deaf_ears  hearing_impaired  \
# 0               True      False              False             False
# 1               True      False              False             False
# 2               True      False              False             False
# 3               True      False              False             False
# 4               True      False              False             False
# ...              ...        ...                ...               ...
# 18058          False      False              False             False
# 18059          False      False              False             False
# 18060          False      False              False             False
# 18061          False      False              False             False
# 18062          False      False              False             False
#
#        tone_deaf  deaf_as_a_post  stone_deaf   deaf
# 0          False           False       False  False
# 1          False           False       False  False
# 2          False           False       False  False
# 3          False           False       False  False
# 4          False           False       False  False
# ...          ...             ...         ...    ...
# 18058      False           False       False   True
# 18059      False           False       False   True
# 18060      False           False       False   True
# 18061      False           False       False   True
# 18062      False           False       False   True
#
# [18063 rows x 18 columns]

# %% [markdown]
# Some articles contain multiple phrases. For example an article may contain "deaf-mute" as well as "hearing-impaired." They currently show up as two separate rows, with duplicate values for everything except the deaf-mute and hearing-impaired columns. One row shows True in the deaf-mute column, and the other row shows True in the hearing-impaired column. We want to merge these two rows into one row where both columns show True.

# %%
if final_df['id'].duplicated().any():
    print('Duplicates: ' + str(final_df['id'].duplicated().sum()))
# Out:
# Duplicates: 587

# %% [markdown]
# I tried to process the duplicates in the data frame like this:

# %%
final_df.groupby(df.columns[0:10].tolist(), as_index=False).max() # DOESNT WORK, DROPS TOO MANY ROWS
# Out:
#                                                 headline        date doc_type  \
# 0                                 'A Little Bit of Help'  1985-09-07  article
# 1          'Beach House,' romantic comedy at Circle Rep.  1985-03-29  article
# 2                     'Noises Off,' With Flawless Timing  1990-07-08  article
# 3                 10TH ANNIVERSARY FOR 'SUMMER EVENINGS'  1985-06-09  article
# 4           A 'STREAMLINED' EDITION OF 1985 OSCAR AWARDS  1985-03-27  article
# ...                                                  ...         ...      ...
# 11952  ‘Wonder Woman’ Could Be the Superhero Women in...  2017-06-04  article
# 11953                                  ‘World Wide Mind’  2011-02-15  article
# 11954  ‘Write When You Get Work’ Review: Backstreet B...  2018-11-22  article
# 11955  ‘Yellow Vests’ Riot in Paris, but Their Anger ...  2018-12-02  article
# 11956  “Rock is the medium of a generation's self‐exp...  1972-11-05  article
#
#       material_type                news_desk       section  \
# 0              News        Metropolitan Desk      New York
# 1              News             Weekend Desk       Theater
# 2              News  Westchester Weekly Desk      New York
# 3            Review  Westchester Weekly Desk      New York
# 4            Review            Cultural Desk        Movies
# ...             ...                      ...           ...
# 11952          News                 Business  Business Day
# 11953          Text                  Science       Science
# 11954        Review                  Weekend        Movies
# 11955          News                  Foreign         World
# 11956      Archives                     None      Archives
#
#                                                 keywords  \
# 0      ['Culture', 'Awards, Decorations and Honors', ...
# 1                                            ['Theater']
# 2                                 ['Reviews', 'Theater']
# 3                                              ['Music']
# 4                      ['MOTION PICTURES', 'Television']
# ...                                                  ...
# 11952  ['Movies', 'Women and Girls', 'Sexual Harassme...
# 11953  ['Books and Literature', 'Science and Technolo...
# 11954                                         ['Movies']
# 11955  ['Yellow Vests Movement', 'Demonstrations, Pro...
# 11956                                          ['Music']
#
#                                                      url  \
# 0      https://www.nytimes.com/1985/09/07/nyregion/ne...
# 1      https://www.nytimes.com/1985/03/29/theater/bro...
# 2      https://www.nytimes.com/1990/07/08/nyregion/th...
# 3      https://www.nytimes.com/1985/06/09/nyregion/mu...
# 4      https://www.nytimes.com/1985/03/27/movies/tv-r...
# ...                                                  ...
# 11952  https://www.nytimes.com/2017/06/04/business/me...
# 11953  https://www.nytimes.com/2011/02/15/science/15s...
# 11954  https://www.nytimes.com/2018/11/22/movies/writ...
# 11955  https://www.nytimes.com/2018/12/02/world/europ...
# 11956  https://www.nytimes.com/1972/11/05/archives/-r...
#
#                                                       id  \
# 0      nyt://article/d9a9b191-341c-5ca2-975e-7c26d0c3...
# 1      nyt://article/1d7824c8-8ec3-5af2-809b-f11b56b3...
# 2      nyt://article/6f7f506a-308a-5679-bc58-79cfa26f...
# 3      nyt://article/801429bd-4a71-5285-8a61-bf2ba672...
# 4      nyt://article/a332e0ad-1165-5bf7-891c-1f1670ea...
# ...                                                  ...
# 11952  nyt://article/234b9c6e-59ed-5dfb-a561-2939c35c...
# 11953  nyt://article/9c18470b-2b77-55bf-863a-fb55bef5...
# 11954  nyt://article/db879a75-4d65-56ff-b5ad-93ecf008...
# 11955  nyt://article/4f02b33e-94f3-5d46-9fa9-71e3c50a...
# 11956  nyt://article/040a0ccd-f2ec-5450-ac0e-45f50646...
#
#                                              byline  deaf_and_dumb  deaf_mute  \
# 0      By Susan Heller Anderson and David W. Dunlap          False      False
# 1                                      By Enid Nemy          False      False
# 2                                    By Alvin Klein          False      False
# 3                                 By Robert Sherman          False      False
# 4                                   By Janet Maslin          False      False
# ...                                             ...            ...        ...
# 11952                              By Jim Rutenberg          False      False
# 11953                            By Michael Chorost          False      False
# 11954                        By Jeannette Catsoulis          False      False
# 11955                              By Adam Nossiter          False      False
# 11956                               By Patrick Carr          False      False
#
#        fell_on_deaf_ears  hearing_impaired  tone_deaf  deaf_as_a_post  \
# 0                  False             False      False           False
# 1                  False              True      False           False
# 2                  False             False      False           False
# 3                  False             False      False           False
# 4                  False             False       True           False
# ...                  ...               ...        ...             ...
# 11952              False              True      False           False
# 11953              False             False      False           False
# 11954              False             False       True           False
# 11955              False             False      False           False
# 11956              False             False       True           False
#
#        stone_deaf   deaf
# 0           False   True
# 1           False   True
# 2           False   True
# 3           False   True
# 4           False  False
# ...           ...    ...
# 11952       False  False
# 11953       False   True
# 11954       False  False
# 11955       False   True
# 11956       False  False
#
# [11957 rows x 18 columns]

# %% [markdown]
# But it didn't work. So I copied duplicates into a separate dataframe, processed them there, removed all copies of them from final_df, then appended the processed dupes to final_df and resorted. *shrug*

# %%
# Process dupes separately
dupes = pd.concat(g for _, g in final_df.groupby('id') if len(g) > 1)
dupes
# Out:
#                                                 headline        date  \
# 3607   M. McClelland, 53; Helped Experiments In Theat...  1993-09-22
# 11882  M. McClelland, 53; Helped Experiments In Theat...  1993-09-22
# 3608           THE HARD-OF-HEARING LIKE THE THEATER, TOO  1983-08-13
# 10169          THE HARD-OF-HEARING LIKE THE THEATER, TOO  1983-08-13
# 3610                                     About Education  1979-03-20
# ...                                                  ...         ...
# 17899     Fractured Lands: How the Arab World Came Apart  2016-08-11
# 4904                                           Deaf Club  2016-04-29
# 17934                                          Deaf Club  2016-04-29
# 4905                                       ‘Magic to Do’  2011-07-25
# 17059                                      ‘Magic to Do’  2011-07-25
#
#          doc_type        material_type       news_desk     section  \
# 3607      article  Obituary; Biography        Obituary  Obituaries
# 11882     article  Obituary; Biography        Obituary  Obituaries
# 3608      article               Letter  Editorial Desk     Opinion
# 10169     article               Letter  Editorial Desk     Opinion
# 3610      article             Archives            None    Archives
# ...           ...                  ...             ...         ...
# 17899  multimedia  Interactive Feature        Magazine    Magazine
# 4904   multimedia            Slideshow      T Magazine  T Magazine
# 17934  multimedia            Slideshow      T Magazine  T Magazine
# 4905   multimedia            Slideshow         Theater     Theater
# 17059  multimedia            Slideshow         Theater     Theater
#
#                                                 keywords  \
# 3607              ['Biographical Information', 'DEATHS']
# 11882             ['Biographical Information', 'DEATHS']
# 3608                             ['TERMS NOT AVAILABLE']
# 10169                            ['TERMS NOT AVAILABLE']
# 3610   ['Colleges and Universities', 'SPECIAL EDUCATI...
# ...                                                  ...
# 17899  ['Middle East and North Africa Unrest (2010- )...
# 4904                               ['Deafness', 'Music']
# 17934                              ['Deafness', 'Music']
# 4905                             ['Theater', 'Deafness']
# 17059                            ['Theater', 'Deafness']
#
#                                                      url  \
# 3607   https://www.nytimes.com/1993/09/22/obituaries/...
# 11882  https://www.nytimes.com/1993/09/22/obituaries/...
# 3608   https://www.nytimes.com/1983/08/13/opinion/l-t...
# 10169  https://www.nytimes.com/1983/08/13/opinion/l-t...
# 3610   https://www.nytimes.com/1979/03/20/archives/ab...
# ...                                                  ...
# 17899  https://www.nytimes.com/interactive/2016/08/11...
# 4904   https://www.nytimes.com/slideshow/2016/04/29/t...
# 17934  https://www.nytimes.com/slideshow/2016/04/29/t...
# 4905   https://www.nytimes.com/slideshow/2009/02/12/t...
# 17059  https://www.nytimes.com/slideshow/2009/02/12/t...
#
#                                                       id  \
# 3607   nyt://article/00742127-b642-510b-a474-a05476c5...
# 11882  nyt://article/00742127-b642-510b-a474-a05476c5...
# 3608   nyt://article/007e25b1-b68b-5bc6-ada2-350415d9...
# 10169  nyt://article/007e25b1-b68b-5bc6-ada2-350415d9...
# 3610   nyt://article/00a73aaf-0717-5760-b9b0-e4c454bc...
# ...                                                  ...
# 17899  nyt://interactive/719faca4-5757-5111-a7e4-19f1...
# 4904   nyt://slideshow/3412e8a3-2e79-5269-a752-7573ec...
# 17934  nyt://slideshow/3412e8a3-2e79-5269-a752-7573ec...
# 4905   nyt://slideshow/bcb62c85-d683-5d1b-b548-0a7b9b...
# 17059  nyt://slideshow/bcb62c85-d683-5d1b-b548-0a7b9b...
#
#                      byline  deaf_and_dumb  deaf_mute  fell_on_deaf_ears  \
# 3607    By Kathleen Teltsch          False      False              False
# 11882   By Kathleen Teltsch          False      False              False
# 3608                    NaN          False      False              False
# 10169                   NaN          False      False              False
# 3610   By Fred M. Hechinger          False      False              False
# ...                     ...            ...        ...                ...
# 17899     By SCOTT ANDERSON          False      False              False
# 4904                    NaN          False      False              False
# 17934                   NaN          False      False              False
# 4905                    NaN          False      False              False
# 17059                   NaN          False      False              False
#
#        hearing_impaired  tone_deaf  deaf_as_a_post  stone_deaf   deaf
# 3607               True      False           False       False  False
# 11882             False      False           False       False   True
# 3608               True      False           False       False  False
# 10169             False      False           False       False   True
# 3610               True      False           False       False  False
# ...                 ...        ...             ...         ...    ...
# 17899             False      False           False       False   True
# 4904               True      False           False       False  False
# 17934             False      False           False       False   True
# 4905               True      False           False       False  False
# 17059             False      False           False       False   True
#
# [1173 rows x 18 columns]

# %% [markdown]
# Merge rows so that there is only one row for each unique id, retaining all True values. Note again that for each unique id, the only thing that differs are the columns containing the True/False values, hence us doing groupby on all the other columns so that we can apply .max() to those True/False columns.
#
# .max() works cuz True > False

# %%
dupes.reset_index(drop=True, inplace=True)
dupes_fixed = dupes.groupby(dupes.columns[0:10].tolist(), as_index=False).max()
dupes_fixed
# Out:
#                                               headline        date doc_type  \
# 0        'Beach House,' romantic comedy at Circle Rep.  1985-03-29  article
# 1                                          DRUNK AGAIN  1985-03-31  article
# 2               HOPE IS OFFERED TO THE HARD-OF-HEARING  1985-08-18  article
# 3            LISTENERS PAY A HIGH PRICE FOR LOUD MUSIC  1990-03-18  article
# 4                                      Personal Health  1990-09-20  article
# ..                                                 ...         ...      ...
# 450          Your Money; Claiming a Pet As a Deduction  1981-03-28  article
# 451   Your Typical Crowded, Swinging, Silent Bar Scene  1994-10-30  article
# 452   ‘Fargo’ Recap: Dead Dogs, Spiders and Pestilence  2014-04-30  article
# 453                         ‘Singing’ With Their Hands  2012-02-11  article
# 454  ‘Switched at Birth,’ a Series Illuminating a W...  2017-01-30  article
#
#     material_type                news_desk          section  \
# 0            News             Weekend Desk          Theater
# 1            News            Magazine Desk         Magazine
# 2            News  Westchester Weekly Desk         New York
# 3            News    Arts and Leisure Desk             Arts
# 4            News            National Desk             U.S.
# ..            ...                      ...              ...
# 450          News           Financial Desk     Business Day
# 451          News     The City Weekly Desk         New York
# 452          News                  Culture             Arts
# 453          News                   Styles  Fashion & Style
# 454          News                  Culture             Arts
#
#                                               keywords  \
# 0                                          ['Theater']
# 1                                 ['English Language']
# 2                              ['TERMS NOT AVAILABLE']
# 3                                ['Music', 'Deafness']
# 4    ['Deafness', 'Children and Youth', 'Implants',...
# ..                                                 ...
# 450  ['ANIMALS', 'Taxation', 'Income Tax', 'Handica...
# 451                               ['Deafness', 'Bars']
# 452                                                 []
# 453  ['Video Recordings and Downloads', 'Music', 'S...
# 454                                     ['Television']
#
#                                                    url  \
# 0    https://www.nytimes.com/1985/03/29/theater/bro...
# 1    https://www.nytimes.com/1985/03/31/magazine/on...
# 2    https://www.nytimes.com/1985/08/18/nyregion/we...
# 3    https://www.nytimes.com/1990/03/18/arts/sound-...
# 4    https://www.nytimes.com/1990/09/20/us/health-p...
# ..                                                 ...
# 450  https://www.nytimes.com/1981/03/28/business/yo...
# 451  https://www.nytimes.com/1994/10/30/nyregion/ne...
# 452  https://artsbeat.blogs.nytimes.com/2014/04/29/...
# 453  https://www.nytimes.com/2012/02/12/fashion/sin...
# 454  https://www.nytimes.com/2017/01/30/arts/televi...
#
#                                                     id  \
# 0    nyt://article/1d7824c8-8ec3-5af2-809b-f11b56b3...
# 1    nyt://article/89c35a34-5440-5541-afbf-3f8f652d...
# 2    nyt://article/82d141c9-c2b9-5324-bc57-1ad2021f...
# 3    nyt://article/a4d01869-7cfa-5f26-9a45-019ca8aa...
# 4    nyt://article/a8eb2607-1042-5b45-92bc-85892bc0...
# ..                                                 ...
# 450  nyt://article/8aa2aceb-e543-5691-b4cc-572cfada...
# 451  nyt://article/1aab92b9-5b05-50b7-bf7a-2b8cef19...
# 452  nyt://article/3a6161c6-023a-5968-a28e-0ea2ecb6...
# 453  nyt://article/0918d106-bd33-59fe-a100-cd3f9a23...
# 454  nyt://article/70949850-b6e8-50c9-9982-1061b7f8...
#
#                         byline  deaf_and_dumb  deaf_mute  fell_on_deaf_ears  \
# 0                 By Enid Nemy          False      False              False
# 1            By William Safire          False      False              False
# 2              By Rosalyn Fein          False      False              False
# 3               By Hans Fantel          False      False              False
# 4             By Jane E. Brody          False      False              False
# ..                         ...            ...        ...                ...
# 450     By Elizabeth M. Fowler          False      False              False
# 451  By Jennifer Kingson Bloom          False      False              False
# 452           By Kate Phillips          False      False              False
# 453        By Austin Considine          False      False              False
# 454         By Neil Genzlinger          False      False              False
#
#      hearing_impaired  tone_deaf  deaf_as_a_post  stone_deaf  deaf
# 0                True      False           False       False  True
# 1                True      False           False       False  True
# 2                True      False           False       False  True
# 3                True      False           False       False  True
# 4                True      False           False       False  True
# ..                ...        ...             ...         ...   ...
# 450              True      False           False       False  True
# 451              True      False           False       False  True
# 452              True      False           False       False  True
# 453              True      False           False       False  True
# 454              True      False           False       False  True
#
# [455 rows x 18 columns]

# %% [markdown]
# Remove all instances of duplicates from final_df.

# %%
final_df = final_df[~final_df['id'].isin(dupes['id'])]
final_final_lol_mybad_df = pd.concat((final_df, dupes_fixed))
final_final_lol_mybad_df.reset_index(inplace=True, drop=True)
final_final_lol_mybad_df
# Out:
#                                                 headline        date doc_type  \
# 0                              THE DEAF AND DUMB WAITER.  1885-12-03  article
# 1              Chad Threatens to Expel Sudanese Refugees  2006-04-14  article
# 2                WELFARE HOTEL CHILDREN: TOMORROW'S POOR  1987-07-16  article
# 3      Wal-Mart Says Oil Prices Held Down Profits for...  2005-08-16  article
# 4       A Space Force? The Idea May Have Merit, Some Say  2018-06-23  article
# ...                                                  ...         ...      ...
# 17340          Your Money; Claiming a Pet As a Deduction  1981-03-28  article
# 17341   Your Typical Crowded, Swinging, Silent Bar Scene  1994-10-30  article
# 17342   ‘Fargo’ Recap: Dead Dogs, Spiders and Pestilence  2014-04-30  article
# 17343                         ‘Singing’ With Their Hands  2012-02-11  article
# 17344  ‘Switched at Birth,’ a Series Illuminating a W...  2017-01-30  article
#
#       material_type             news_desk          section  \
# 0          Archives                  None         Archives
# 1              News         International            World
# 2              News     Metropolitan Desk         New York
# 3              News              Business     Business Day
# 4              News            Washington             U.S.
# ...             ...                   ...              ...
# 17340          News        Financial Desk     Business Day
# 17341          News  The City Weekly Desk         New York
# 17342          News               Culture             Arts
# 17343          News                Styles  Fashion & Style
# 17344          News               Culture             Arts
#
#                                                 keywords  \
# 0                                                     []
# 1                                                     []
# 2      ['Homeless Persons', 'HOTELS AND MOTELS', 'Chi...
# 3                                    ['Company Reports']
# 4      ['Space and Astronomy', 'United States Defense...
# ...                                                  ...
# 17340  ['ANIMALS', 'Taxation', 'Income Tax', 'Handica...
# 17341                               ['Deafness', 'Bars']
# 17342                                                 []
# 17343  ['Video Recordings and Downloads', 'Music', 'S...
# 17344                                     ['Television']
#
#                                                      url  \
# 0      https://www.nytimes.com/1885/12/03/archives/th...
# 1      https://www.nytimes.com/2006/04/14/world/chad-...
# 2      https://www.nytimes.com/1987/07/16/nyregion/we...
# 3      https://www.nytimes.com/2005/08/16/business/wa...
# 4      https://www.nytimes.com/2018/06/23/us/politics...
# ...                                                  ...
# 17340  https://www.nytimes.com/1981/03/28/business/yo...
# 17341  https://www.nytimes.com/1994/10/30/nyregion/ne...
# 17342  https://artsbeat.blogs.nytimes.com/2014/04/29/...
# 17343  https://www.nytimes.com/2012/02/12/fashion/sin...
# 17344  https://www.nytimes.com/2017/01/30/arts/televi...
#
#                                                       id  \
# 0      nyt://article/0074c23c-1ff6-5bc7-85d9-e56a5af3...
# 1      nyt://article/00bb19d7-2ba6-5072-8e6b-3159730d...
# 2      nyt://article/01670df3-ae07-5eb6-8862-7bd834bf...
# 3      nyt://article/0175ac61-cc62-5cdc-923c-f5efb8ec...
# 4      nyt://article/01b8b8a5-7d0c-592a-a283-a9ccd3d8...
# ...                                                  ...
# 17340  nyt://article/8aa2aceb-e543-5691-b4cc-572cfada...
# 17341  nyt://article/1aab92b9-5b05-50b7-bf7a-2b8cef19...
# 17342  nyt://article/3a6161c6-023a-5968-a28e-0ea2ecb6...
# 17343  nyt://article/0918d106-bd33-59fe-a100-cd3f9a23...
# 17344  nyt://article/70949850-b6e8-50c9-9982-1061b7f8...
#
#                           byline  deaf_and_dumb  deaf_mute  fell_on_deaf_ears  \
# 0                            NaN           True      False              False
# 1                  By Marc Lacey           True      False              False
# 2                By Lydia Chavez           True      False              False
# 3                By Roben Farzad           True      False              False
# 4               By Helene Cooper           True      False              False
# ...                          ...            ...        ...                ...
# 17340     By Elizabeth M. Fowler          False      False              False
# 17341  By Jennifer Kingson Bloom          False      False              False
# 17342           By Kate Phillips          False      False              False
# 17343        By Austin Considine          False      False              False
# 17344         By Neil Genzlinger          False      False              False
#
#        hearing_impaired  tone_deaf  deaf_as_a_post  stone_deaf   deaf
# 0                 False      False           False       False  False
# 1                 False      False           False       False  False
# 2                 False      False           False       False  False
# 3                 False      False           False       False  False
# 4                 False      False           False       False  False
# ...                 ...        ...             ...         ...    ...
# 17340              True      False           False       False   True
# 17341              True      False           False       False   True
# 17342              True      False           False       False   True
# 17343              True      False           False       False   True
# 17344              True      False           False       False   True
#
# [17345 rows x 18 columns]

# %%
print('Duplicates: ' + str(final_final_lol_mybad_df['id'].duplicated().sum()))
# Out:
# Duplicates: 0

# %%
final_final_lol_mybad_df.to_csv('data/all.csv', index=False)
